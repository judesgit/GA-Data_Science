# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model

# %%
# Reading in the .csv file
df = pd.read_csv('final_project.csv', index_col=0)
df.head(20)
# Out:
#                                  Expenditure       2005       2006       2007  \
# 0         Total National Health Expenditures  2,023,744  2,156,158  2295307.0
# 1                              Out of pocket    263,815    273,254   290000.0
# 2                           Health Insurance  1,414,078  1,517,387  1609250.0
# 3                   Private Health Insurance    701,176    737,122   776176.0
# 4                                   Medicare    339,762    403,690   432751.0
# 5                       Medicaid (Title XIX)    309,275    306,584   325746.0
# 6                                  Federal      177,461    173,879   185485.0
# 7                            State and Local    131,814    132,705   140261.0
# 8             CHIP (Title XIX and Title XXI)      7,566      8,366     9117.0
#
#         2008       2009       2010       2011       2012       2013  \
# 0  2399121.0  2495414.0  2598823.0  2689349.0  2797260.0  2879008.0
# ...

# %%
#df.2005 = df.2005.str.replace(' -   ', '0')
df['2005'] = df['2005'].str.replace(',', '')
df['2005'] = df['2005'].astype(float)

# %%
df['2006'] = df['2006'].str.replace(',', '')
df['2006'] = df['2006'].astype(float)

# %%
df.head(20)
# Out:
#                                  Expenditure       2005       2006       2007  \
# 0         Total National Health Expenditures  2023744.0  2156158.0  2295307.0
# 1                              Out of pocket   263815.0   273254.0   290000.0
# 2                           Health Insurance  1414078.0  1517387.0  1609250.0
# 3                   Private Health Insurance   701176.0   737122.0   776176.0
# 4                                   Medicare   339762.0   403690.0   432751.0
# 5                       Medicaid (Title XIX)   309275.0   306584.0   325746.0
# 6                                  Federal     177461.0   173879.0   185485.0
# 7                            State and Local   131814.0   132705.0   140261.0
# 8             CHIP (Title XIX and Title XXI)     7566.0     8366.0     9117.0
#
#         2008       2009       2010       2011       2012       2013  \
# 0  2399121.0  2495414.0  2598823.0  2689349.0  2797260.0  2879008.0
# ...

# %%
df.drop(df.index[[3,4,5,8]])
# Out:
#                                  Expenditure       2005       2006       2007  \
# 0         Total National Health Expenditures  2023744.0  2156158.0  2295307.0
# 1                              Out of pocket   263815.0   273254.0   290000.0
# 2                           Health Insurance  1414078.0  1517387.0  1609250.0
# 6                                  Federal     177461.0   173879.0   185485.0
# 7                            State and Local   131814.0   132705.0   140261.0
#
#         2008       2009       2010       2011       2012       2013  \
# 0  2399121.0  2495414.0  2598823.0  2689349.0  2797260.0  2879008.0
# 1   295184.0   293723.0   299742.0   309973.0   318330.0   325189.0
# 2  1695968.0  1796424.0  1876922.0  1950187.0  2022904.0  2087804.0
# 6   203084.0   247326.0   266360.0   247125.0   243251.0   256907.0
# 7   141129.0   127094.0   130865.0   159619.0   179438.0   188454.0
#
#         2014       2015       2016
# 0  3026157.0  3200815.0  3337248.0
# ...

# %%
df.drop('2005', axis = 1)
# Out:
#                                  Expenditure       2006       2007       2008  \
# 0         Total National Health Expenditures  2156158.0  2295307.0  2399121.0
# 1                              Out of pocket   273254.0   290000.0   295184.0
# 2                           Health Insurance  1517387.0  1609250.0  1695968.0
# 3                   Private Health Insurance   737122.0   776176.0   802857.0
# 4                                   Medicare   403690.0   432751.0   466971.0
# 5                       Medicaid (Title XIX)   306584.0   325746.0   344214.0
# 6                                  Federal     173879.0   185485.0   203084.0
# 7                            State and Local   132705.0   140261.0   141129.0
# 8             CHIP (Title XIX and Title XXI)     8366.0     9117.0    10210.0
#
#         2009       2010       2011       2012       2013       2014  \
# 0  2495414.0  2598823.0  2689349.0  2797260.0  2879008.0  3026157.0
# ...

# %%
df.to_csv('final_project_v2.csv')
