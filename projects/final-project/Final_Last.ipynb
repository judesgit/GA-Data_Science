# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model
# Out:
# /Users/judenwosu/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_csv('US National Health Expenditure Data.csv', index_col=0)
df.head(10)
# Out:
#                                                    Unnamed: 1 Unnamed: 2  \
# NATIONAL HEALTH EXPENDITURES BY TYPE OF SERVICE...
# Expenditure Amount (Millions)                            1960       1961
# Total National Health Expenditures                     27,214     29,138
#      Out of pocket                                     12,949     13,357
#      Health Insurance                                   7,497      8,236
#           Private Health Insurance                      5,812      6,468
#           Medicare                                       -          -
#           Medicaid (Title XIX)                           -          -
#                           Federal                        -          -
#                           State and Local                -          -
#           CHIP (Title XIX and Title XXI)                 -          -
#
#                                                    Unnamed: 3 Unnamed: 4  \
# NATIONAL HEALTH EXPENDITURES BY TYPE OF SERVICE...
# ...

# %%
df["Years"] = pd.to_datetime(df["Years"], format='%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'Years'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df.shape
# Out:
# (543, 57)

# %%
plt.plot(df["Total CMS Prgs"], df["Investment"], label="Investment")
plt.plot(df["Total CMS Prgs"], df["Pub Hlth Act"], label="Pub Hlth Act")
plt.xlabel("Years")
plt.ylabel("Health Expenses")
plt.title("US Healthcare Expenditure")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'Pub Hlth Act'
#
# During handling of the above exception, another exception occurred:
#
# ...
