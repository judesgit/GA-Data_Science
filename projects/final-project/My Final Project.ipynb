# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model

# %%
# Reading in the .csv file
df = pd.read_csv('project_df.csv')
df.head(20)
# Out:
#     Unnamed: 0                                 Expenditure  Year_2007  \
# 0            0          Total National Health Expenditures  2,295,307
# 1            1                               Out of pocket    290,000
# 2            2                            Health Insurance  1,609,250
# 3            3                    Private Health Insurance    776,176
# 4            4                                    Medicare    432,751
# 5            5                        Medicaid (Title XIX)    325,746
# 6            6                                   Federal      185,485
# 7            7                             State and Local    140,261
# 8            8              CHIP (Title XIX and Title XXI)      9,117
# 9            9                                   Federal        6,316
# 10          10                             State and Local      2,801
# 11          11                       Department of Defense     32,262
# ...

# %%
print (df.set_index('Expenditure').T)

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'Expenditure', 'Year_2007', 'Year_2008', 'Year_2009',
#        'Year_2010', 'Year_2011', 'Year_2012', 'Year_2013', 'Year_2014',
#        'Year_2015', 'Year_2016'], dtype=object)

# %%
df[['Year_2007', 'Year_2008', 'Year_2009', 'Year_2010', 'Year_2011',
                 'Year_2012', 'Year_2013', 'Year_2014', 'Year_2015', 'Year_2016']].dropna()
# Out:
#      Year_2007  Year_2008  Year_2009  Year_2010  Year_2011  Year_2012  \
# 0    2,295,307  2,399,121  2,495,414  2,598,823  2,689,349  2,797,260
# 1      290,000    295,184    293,723    299,742    309,973    318,330
# 2    1,609,250  1,695,968  1,796,424  1,876,922  1,950,187  2,022,904
# 3      776,176    802,857    832,906    864,344    898,631    928,211
# 4      432,751    466,971    498,859    519,787    544,679    569,634
# 5      325,746    344,214    374,421    397,226    406,744    422,688
# 6      185,485    203,084    247,326    266,360    247,125    243,251
# 7      140,261    141,129    127,094    130,865    159,619    179,438
# 8        9,117     10,210     11,106     11,540     11,990     12,629
# 9        6,316      7,126      7,812      8,052      8,377      8,780
# 10       2,801      3,084      3,293      3,489      3,613      3,848
# 11      32,262     34,031     36,670     38,301     39,973     39,984
# ...

# %%
df['Year_2007'].unique()
# Out:
# array(['2,295,307', '290,000', '1,609,250', '776,176', '432,751',
#        '325,746', '185,485', '140,261', '9,117', '6,316', '2,801',
#        '32,262', '33,198', '191,693', '4,543', '89,648', '2,569', '41,334',
#        '6,928', '3,763', '600', '3,163', '497', '373', '124', '6,721',
#        '3,166', '28,631', '3,895', '65,969', '9,696', '56,273', '138,395',
#        '42,576', '95,818', '767,613', '301', '2,156,912', '1,918,436',
#        '1,451,726', '671,404', '408,710', '301,109', '171,852', '129,257',
#        '7,766', '5,380', '2,386', '29,667', '33,070', '176,709', '2,468',
#        '26,915', '3,529', '597', '2,932', '443', '332', '110', '6,606',
#        '3,105', '717,585', '691,887', '22,783', '599,819', '250,498',
#        '193,081', '117,182', '67,214', '49,968', '2,634', '1,800', '834',
#        '13,716', '22,707', '69,285', ' -   ', '36,051', '1,290', '11,960',
#        '2,160', '320', '55', '265', '118', '89', '29', '1,282', '162',
# ...

# %%
df.Year_2007 = df.Year_2007.str.replace(' -   ', '0')
df['Year_2007'] = df['Year_2007'].str.replace(',', '')
df['Year_2007'] = df['Year_2007'].astype(float)

# %%
int('1234')
# Out:
# 1234

# %%
# Quick plot of the data using seaborn
sns.pairplot(df[['Year_2007', 'Year_2008', 'Year_2009', 'Year_2010', 'Year_2011', 'Year_2012', 'Year_2013', 'Year_2014', 'Year_2015', 'Year_2016']].dropna())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-5f9e0186b967> in <module>()
#       1 # Quick plot of the data using seaborn
# ----> 2 sns.pairplot(df[['Year_2007', 'Year_2008', 'Year_2009', 'Year_2010', 'Year_2011', 'Year_2012', 'Year_2013', 'Year_2014', 'Year_2015', 'Year_2016']].dropna())
#
# ~/anaconda/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2017                     hue_order=hue_order, palette=palette,
#    2018                     diag_sharey=diag_sharey,
# -> 2019                     size=size, aspect=aspect, dropna=dropna, **grid_kws)
#    2020
#    2021     # Add the markers here as PairGrid has figured out how many levels of the
#
# ...
