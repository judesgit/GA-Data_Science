# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sb
import statsmodels.api as sm
from sklearn import linear_model

# %%
df = pd.read_csv('US_health_expenditure.csv', index_col=0)

# %%
df.head(300)
# Out:
#                                           Expenditure       2005       2006  \
# 0                  Total National Health Expenditures  2,023,744  2,156,158
# 1                                       Out of pocket    263,815    273,254
# 2                                    Health Insurance  1,414,078  1,517,387
# 3                            Private Health Insurance    701,176    737,122
# 4                                            Medicare    339,762    403,690
# 5                                Medicaid (Title XIX)    309,275    306,584
# 6                                           Federal      177,461    173,879
# 7                                     State and Local    131,814    132,705
# 8                      CHIP (Title XIX and Title XXI)      7,566      8,366
# 9                                           Federal        5,254      5,756
# 10                                    State and Local      2,313      2,610
# ...

# %%
df.shape
# Out:
# (542, 13)

# %%
df.drop(df.columns[1:3], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#                                  Expenditure       2007       2008       2009  \
# 0         Total National Health Expenditures  2295307.0  2399121.0  2495414.0
# 1                              Out of pocket   290000.0   295184.0   293723.0
# 2                           Health Insurance  1609250.0  1695968.0  1796424.0
# 3                   Private Health Insurance   776176.0   802857.0   832906.0
# 4                                   Medicare   432751.0   466971.0   498859.0
# 5                       Medicaid (Title XIX)   325746.0   344214.0   374421.0
# 6                                  Federal     185485.0   203084.0   247326.0
# 7                            State and Local   140261.0   141129.0   127094.0
# 8             CHIP (Title XIX and Title XXI)     9117.0    10210.0    11106.0
# 9                                  Federal       6316.0     7126.0     7812.0
#
#         2010       2011       2012       2013       2014       2015       2016
# ...

# %% [markdown]
# #DATA EXPLORATION

# %%
var1_data = df[df.Expenditure == 'Health Insurance']  # Comparing the Health Insurance data for the listed years

# %%
plt.plot(df["2007"], df["2015"], label="2015")
plt.plot(df["2007"], df["2016"], label="2016")
plt.xlabel("Selected Year (2007)")
plt.ylabel("Expenditure")
plt.title("US Annual Health Insurance Expenditure")
plt.legend()
plt.show()

# %%
sb.factorplot(
    x='2007',
    y='2016',
    data=var1_data, 
    kind='box'
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-789fc2211bd7> in <module>()
#       3     y='2016',
#       4     data=var1_data,
# ----> 5     kind='box'
#       6 )
#
# ~/anaconda/lib/python3.6/site-packages/seaborn/categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3478     # so we need to define ``palette`` to get default behavior for the
#    3479     # categorical functions
# -> 3480     p.establish_colors(color, palette, 1)
#    3481     if kind != "point" or hue is not None:
#    3482         palette = p.colors
#
# ~/anaconda/lib/python3.6/site-packages/seaborn/categorical.py in establish_colors(self, color, palette, saturation)
# ...
