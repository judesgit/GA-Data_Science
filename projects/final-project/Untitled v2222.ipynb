# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model

# %%
# Reading in the .csv file
df = pd.read_csv('US National Health Expenditure Data.csv', header=1)
df.head(20)
# Out:
#                  Expenditure Amount (Millions)    1960    1961    1962  \
# 0           Total National Health Expenditures  27,214  29,138  31,842
# 1                                Out of pocket  12,949  13,357  14,255
# 2                             Health Insurance   7,497   8,236   8,999
# 3                     Private Health Insurance   5,812   6,468   7,178
# 4                                     Medicare    -       -       -
# 5                         Medicaid (Title XIX)    -       -       -
# 6                                    Federal      -       -       -
# 7                              State and Local    -       -       -
# 8               CHIP (Title XIX and Title XXI)    -       -       -
# 9                                    Federal      -       -       -
# 10                             State and Local    -       -       -
# 11                       Department of Defense     788     836     860
# ...

# %%
# This is to rename the "Expenditure Amount (Millions)" column to "Expenditure" for ease of use
df.rename(columns = {'Expenditure Amount (Millions)':'Expenditure'}, inplace=True)

# %%
df
# Out:
#                                            Expenditure    1960    1961  \
# 0                   Total National Health Expenditures  27,214  29,138
# 1                                        Out of pocket  12,949  13,357
# 2                                     Health Insurance   7,497   8,236
# 3                             Private Health Insurance   5,812   6,468
# 4                                             Medicare    -       -
# 5                                 Medicaid (Title XIX)    -       -
# 6                                            Federal      -       -
# 7                                      State and Local    -       -
# 8                       CHIP (Title XIX and Title XXI)    -       -
# 9                                            Federal      -       -
# 10                                     State and Local    -       -
# 11                               Department of Defense     788     836
# ...

# %%
df.drop(df.columns[1:46], axis=1, inplace=True)

# %%
df
# Out:
#                                            Expenditure       2005       2006  \
# 0                   Total National Health Expenditures  2,023,744  2,156,158
# 1                                        Out of pocket    263,815    273,254
# 2                                     Health Insurance  1,414,078  1,517,387
# 3                             Private Health Insurance    701,176    737,122
# 4                                             Medicare    339,762    403,690
# 5                                 Medicaid (Title XIX)    309,275    306,584
# 6                                            Federal      177,461    173,879
# 7                                      State and Local    131,814    132,705
# 8                       CHIP (Title XIX and Title XXI)      7,566      8,366
# 9                                            Federal        5,254      5,756
# 10                                     State and Local      2,313      2,610
# ...

# %%
# To drop the NULL values from the dataset
df.dropna()
df.head(10)
# Out:
#                                  Expenditure       2005       2006       2007  \
# 0         Total National Health Expenditures  2,023,744  2,156,158  2,295,307
# 1                              Out of pocket    263,815    273,254    290,000
# 2                           Health Insurance  1,414,078  1,517,387  1,609,250
# 3                   Private Health Insurance    701,176    737,122    776,176
# 4                                   Medicare    339,762    403,690    432,751
# 5                       Medicaid (Title XIX)    309,275    306,584    325,746
# 6                                  Federal      177,461    173,879    185,485
# 7                            State and Local    131,814    132,705    140,261
# 8             CHIP (Title XIX and Title XXI)      7,566      8,366      9,117
# 9                                  Federal        5,254      5,756      6,316
#
#         2008       2009       2010       2011       2012       2013  \
# ...

# %%
df.columns.values
# Out:
# array(['Expenditure', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016'], dtype=object)

# %%
df[['2005', '2006', '2007', '2008', '2009', '2010', '2011',
                 '2012', '2013', '2014', '2015', '2016']].dropna()
# Out:
#           2005       2006       2007       2008       2009       2010  \
# 0    2,023,744  2,156,158  2,295,307  2,399,121  2,495,414  2,598,823
# 1      263,815    273,254    290,000    295,184    293,723    299,742
# 2    1,414,078  1,517,387  1,609,250  1,695,968  1,796,424  1,876,922
# 3      701,176    737,122    776,176    802,857    832,906    864,344
# 4      339,762    403,690    432,751    466,971    498,859    519,787
# 5      309,275    306,584    325,746    344,214    374,421    397,226
# 6      177,461    173,879    185,485    203,084    247,326    266,360
# 7      131,814    132,705    140,261    141,129    127,094    130,865
# 8        7,566      8,366      9,117     10,210     11,106     11,540
# 9        5,254      5,756      6,316      7,126      7,812      8,052
# 10       2,313      2,610      2,801      3,084      3,293      3,489
# 11      26,496     29,765     32,262     34,031     36,670     38,301
# ...

# %%
df['2007'] = df['2007'].str.replace(' -   ', '0')
df['2007'] = df['2007'].str.replace(',', '')
df['2007'] = df['2007'].astype(float)

# %%
df['2008'] = df['2008'].str.replace(' -   ', '0')
df['2008'] = df['2008'].str.replace(',', '')
df['2008'] = df['2008'].astype(float)

# %%
df['2009'] = df['2009'].str.replace(' -   ', '0')
df['2009'] = df['2009'].str.replace(',', '')
df['2009'] = df['2009'].astype(float)

# %%
df['2010'] = df['2010'].str.replace(' -   ', '0')
df['2010'] = df['2010'].str.replace(',', '')
df['2010'] = df['2010'].astype(float)

# %%
df['2011'] = df['2011'].str.replace(' -   ', '0')
df['2011'] = df['2011'].str.replace(',', '')
df['2011'] = df['2011'].astype(float)

# %%
df['2012'] = df['2012'].str.replace(' -   ', '0')
df['2012'] = df['2012'].str.replace(',', '')
df['2012'] = df['2012'].astype(float)

# %%
df['2013'] = df['2013'].str.replace(' -   ', '0')
df['2013'] = df['2013'].str.replace(',', '')
df['2013'] = df['2013'].astype(float)

# %%
df['2014'] = df['2014'].str.replace(' -   ', '0')
df['2014'] = df['2014'].str.replace(',', '')
df['2014'] = df['2014'].astype(float)

# %%
df['2015'] = df['2015'].str.replace(' -   ', '0')
df['2015'] = df['2015'].str.replace(',', '')
df['2015'] = df['2015'].astype(float)

# %%
df['2016'] = df['2016'].str.replace(' -   ', '0')
df['2016'] = df['2016'].str.replace(',', '')
df['2016'] = df['2016'].astype(float)

# %%
project_table = pd.DataFrame(df)
project_table.to_csv("project_table.csv")
