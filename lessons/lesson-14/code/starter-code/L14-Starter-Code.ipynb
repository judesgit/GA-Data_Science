# %%
import pandas as pd
import json

data = pd.read_csv("../../../lesson-13/code/dataset/stumbleupon.tsv", sep='\t')
data['title'] = data.boilerplate.map(lambda x: json.loads(x).get('title', ''))
data['body'] = data.boilerplate.map(lambda x: json.loads(x).get('body', ''))
data.head()
# Out:
#                                                  url  urlid  \
# 0  http://www.bloomberg.com/news/2010-12-23/ibm-p...   4042
# 1  http://www.popsci.com/technology/article/2012-...   8471
# 2  http://www.menshealth.com/health/flu-fighting-...   1164
# 3  http://www.dumblittleman.com/2007/12/10-foolpr...   6684
# 4  http://bleacherreport.com/articles/1205138-the...   9006
#
#                                          boilerplate alchemy_category  \
# 0  {"title":"IBM Sees Holographic Calls Air Breat...         business
# 1  {"title":"The Fully Electronic Futuristic Star...       recreation
# 2  {"title":"Fruits that Fight the Flu fruits tha...           health
# 3  {"title":"10 Foolproof Tips for Better Sleep "...           health
# 4  {"title":"The 50 Coolest Jerseys You Didn t Kn...           sports
#
#   alchemy_category_score  avglinksize  commonlinkratio_1  commonlinkratio_2  \
# 0               0.789131     2.055556           0.676471           0.205882
# 1               0.574147     3.677966           0.508021           0.288770
# 2               0.996526     2.382883           0.562016           0.321705
# 3               0.801248     1.543103           0.400000           0.100000
# 4               0.719157     2.676471           0.500000           0.222222
#
#    commonlinkratio_3  commonlinkratio_4  \
# 0           0.047059           0.023529
# 1           0.213904           0.144385
# 2           0.120155           0.042636
# 3           0.016667           0.000000
# 4           0.123457           0.043210
#
#                          ...                          linkwordscore  \
# 0                        ...                                     24
# 1                        ...                                     40
# 2                        ...                                     55
# 3                        ...                                     24
# 4                        ...                                     14
#
#    news_front_page  non_markup_alphanum_characters  numberOfLinks  \
# 0                0                            5424            170
# 1                0                            4973            187
# 2                0                            2240            258
# 3                0                            2737            120
# 4                0                           12032            162
#
#    numwords_in_url  parametrizedLinkRatio  spelling_errors_ratio label  \
# 0                8               0.152941               0.079130     0
# 1                9               0.181818               0.125448     1
# 2               11               0.166667               0.057613     1
# 3                5               0.041667               0.100858     1
# 4               10               0.098765               0.082569     0
#
#                                                title  \
# 0  IBM Sees Holographic Calls Air Breathing Batte...
# 1  The Fully Electronic Futuristic Starting Gun T...
# 2  Fruits that Fight the Flu fruits that fight th...
# 3                10 Foolproof Tips for Better Sleep
# 4  The 50 Coolest Jerseys You Didn t Know Existed...
#
#                                                 body
# 0  A sign stands outside the International Busine...
# 1  And that can be carried on a plane without the...
# 2  Apples The most popular source of antioxidants...
# 3  There was a period in my life when I had a lot...
# 4  Jersey sales is a curious business Whether you...
#
# [5 rows x 29 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

bodies = data['body'].dropna('').copy()
vectorizer = CountVectorizer(max_features=1000, binary=False, stop_words='english')

# %%
id2word = dict(enumerate(vectorizer.get_feature_names()))

# %%
id2word
# Out:
# {0: '00',
#  1: '000',
#  2: '08',
#  3: '09',
#  4: '10',
#  5: '100',
#  6: '11',
#  7: '12',
#  8: '13',
#  9: '14',
#  10: '15',
#  11: '16',
#  12: '17',
#  13: '18',
#  14: '19',
#  15: '20',
#  16: '2005',
#  17: '2006',
#  18: '2007',
#  19: '2008',
#  20: '2009',
#  21: '2010',
#  22: '2011',
#  23: '2012',
#  24: '21',
#  25: '22',
#  26: '23',
#  27: '24',
#  28: '25',
#  29: '26',
#  30: '27',
#  31: '28',
#  32: '29',
#  33: '30',
#  34: '31',
#  35: '35',
#  36: '350',
#  37: '40',
#  38: '45',
#  39: '50',
#  40: '60',
#  41: 'ability',
#  42: 'able',
#  43: 'according',
#  44: 'actually',
#  45: 'ad',
#  46: 'add',
#  47: 'added',
#  48: 'adding',
#  49: 'addition',
#  50: 'additional',
#  51: 'age',
#  52: 'ago',
#  53: 'air',
#  54: 'alcohol',
#  55: 'allow',
#  56: 'amazing',
#  57: 'america',
#  58: 'american',
#  59: 'app',
#  60: 'apple',
#  61: 'apples',
#  62: 'april',
#  63: 'area',
#  64: 'aren',
#  65: 'art',
#  66: 'article',
#  67: 'aside',
#  68: 'ask',
#  69: 'asked',
#  70: 'athletes',
#  71: 'attention',
#  72: 'august',
#  73: 'author',
#  74: 'available',
#  75: 'average',
#  76: 'avocado',
#  77: 'avoid',
#  78: 'away',
#  79: 'awesome',
#  80: 'baby',
#  81: 'background',
#  82: 'bacon',
#  83: 'bad',
#  84: 'bag',
#  85: 'bake',
#  86: 'baked',
#  87: 'baking',
#  88: 'ball',
#  89: 'balls',
#  90: 'banana',
#  91: 'bar',
#  92: 'bars',
#  93: 'base',
#  94: 'based',
#  95: 'basic',
#  96: 'basil',
#  97: 'batter',
#  98: 'bean',
#  99: 'beans',
#  100: 'beat',
#  101: 'beautiful',
#  102: 'beauty',
#  103: 'beef',
#  104: 'beer',
#  105: 'begin',
#  106: 'believe',
#  107: 'benefits',
#  108: 'best',
#  109: 'better',
#  110: 'big',
#  111: 'bit',
#  112: 'black',
#  113: 'blend',
#  114: 'blog',
#  115: 'blood',
#  116: 'blue',
#  117: 'board',
#  118: 'body',
#  119: 'boil',
#  120: 'book',
#  121: 'bought',
#  122: 'bowl',
#  123: 'box',
#  124: 'brain',
#  125: 'bread',
#  126: 'break',
#  127: 'breakfast',
#  128: 'breast',
#  129: 'bring',
#  130: 'broccoli',
#  131: 'brown',
#  132: 'brownies',
#  133: 'business',
#  134: 'butter',
#  135: 'buy',
#  136: 'buzz',
#  137: 'cake',
#  138: 'cakes',
#  139: 'california',
#  140: 'called',
#  141: 'calories',
#  142: 'came',
#  143: 'campaign',
#  144: 'cancer',
#  145: 'candy',
#  146: 'car',
#  147: 'caramel',
#  148: 'care',
#  149: 'case',
#  150: 'category',
#  151: 'cause',
#  152: 'cells',
#  153: 'center',
#  154: 'certain',
#  155: 'chance',
#  156: 'change',
#  157: 'check',
#  158: 'cheddar',
#  159: 'cheese',
#  160: 'cheesecake',
#  161: 'chef',
#  162: 'chicken',
#  163: 'child',
#  164: 'children',
#  165: 'chili',
#  166: 'chinese',
#  167: 'chip',
#  168: 'chips',
#  169: 'chocolate',
#  170: 'choice',
#  171: 'cholesterol',
#  172: 'choose',
#  173: 'chopped',
#  174: 'christmas',
#  175: 'cinnamon',
#  176: 'city',
#  177: 'class',
#  178: 'classic',
#  179: 'clean',
#  180: 'clear',
#  181: 'click',
#  182: 'close',
#  183: 'clothing',
#  184: 'cloves',
#  185: 'coat',
#  186: 'cocoa',
#  187: 'coconut',
#  188: 'coffee',
#  189: 'cold',
#  190: 'collection',
#  191: 'college',
#  192: 'color',
#  193: 'com',
#  194: 'combination',
#  195: 'combine',
#  196: 'combined',
#  197: 'come',
#  198: 'comes',
#  199: 'coming',
#  200: 'comment',
#  201: 'comments',
#  202: 'common',
#  203: 'community',
#  204: 'company',
#  205: 'complete',
#  206: 'completely',
#  207: 'computer',
#  208: 'concept',
#  209: 'container',
#  210: 'content',
#  211: 'continue',
#  212: 'control',
#  213: 'cook',
#  214: 'cooked',
#  215: 'cookie',
#  216: 'cookies',
#  217: 'cooking',
#  218: 'cool',
#  219: 'corn',
#  220: 'cost',
#  221: 'couldn',
#  222: 'country',
#  223: 'couple',
#  224: 'course',
#  225: 'cover',
#  226: 'covered',
#  227: 'cream',
#  228: 'creamy',
#  229: 'create',
#  230: 'created',
#  231: 'crisp',
#  232: 'crumbs',
#  233: 'crust',
#  234: 'culture',
#  235: 'cup',
#  236: 'cupcake',
#  237: 'cupcakes',
#  238: 'cups',
#  239: 'cut',
#  240: 'daily',
#  241: 'damascus',
#  242: 'dark',
#  243: 'data',
#  244: 'date',
#  245: 'day',
#  246: 'days',
#  247: 'deal',
#  248: 'death',
#  249: 'december',
#  250: 'decided',
#  251: 'deep',
#  252: 'definitely',
#  253: 'degrees',
#  254: 'delicious',
#  255: 'design',
#  256: 'designed',
#  257: 'dessert',
#  258: 'desserts',
#  259: 'did',
#  260: 'didn',
#  261: 'diet',
#  262: 'different',
#  263: 'dinner',
#  264: 'dip',
#  265: 'directions',
#  266: 'disease',
#  267: 'dish',
#  268: 'dishes',
#  269: 'display',
#  270: 'div',
#  271: 'does',
#  272: 'doesn',
#  273: 'dog',
#  274: 'doing',
#  275: 'don',
#  276: 'double',
#  277: 'dough',
#  278: 'dr',
#  279: 'dress',
#  280: 'dried',
#  281: 'drink',
#  282: 'drinking',
#  283: 'drop',
#  284: 'drug',
#  285: 'dry',
#  286: 'early',
#  287: 'easier',
#  288: 'easily',
#  289: 'easy',
#  290: 'eat',
#  291: 'eating',
#  292: 'edges',
#  293: 'effect',
#  294: 'effects',
#  295: 'egg',
#  296: 'eggs',
#  297: 'electric',
#  298: 'email',
#  299: 'end',
#  300: 'energy',
#  301: 'enjoy',
#  302: 'entire',
#  303: 'especially',
#  304: 'evenly',
#  305: 'event',
#  306: 'exactly',
#  307: 'example',
#  308: 'exercise',
#  309: 'experience',
#  310: 'extra',
#  311: 'extract',
#  312: 'eye',
#  313: 'eyes',
#  314: 'face',
#  315: 'facebook',
#  316: 'fact',
#  317: 'fall',
#  318: 'false',
#  319: 'family',
#  320: 'fan',
#  321: 'fans',
#  322: 'far',
#  323: 'fashion',
#  324: 'fast',
#  325: 'fat',
#  326: 'favorite',
#  327: 'features',
#  328: 'february',
#  329: 'feel',
#  330: 'feeling',
#  331: 'feet',
#  332: 'fiber',
#  333: 'field',
#  334: 'filled',
#  335: 'filling',
#  336: 'finally',
#  337: 'fine',
#  338: 'firm',
#  339: 'fish',
#  340: 'fit',
#  341: 'fitness',
#  342: 'flashvars',
#  343: 'flat',
#  344: 'flavor',
#  345: 'flavors',
#  346: 'flour',
#  347: 'foil',
#  348: 'fold',
#  349: 'follow',
#  350: 'following',
#  351: 'food',
#  352: 'foods',
#  353: 'football',
#  354: 'form',
#  355: 'free',
#  356: 'freezer',
#  357: 'french',
#  358: 'fresh',
#  359: 'fridge',
#  360: 'fried',
#  361: 'friend',
#  362: 'friends',
#  363: 'frosting',
#  364: 'frozen',
#  365: 'fruit',
#  366: 'fruits',
#  367: 'fry',
#  368: 'fun',
#  369: 'function',
#  370: 'funny',
#  371: 'future',
#  372: 'game',
#  373: 'games',
#  374: 'garlic',
#  375: 'gently',
#  376: 'gets',
#  377: 'getting',
#  378: 'ginger',
#  379: 'girl',
#  380: 'given',
#  381: 'gives',
#  382: 'glass',
#  383: 'goes',
#  384: 'going',
#  385: 'gold',
#  386: 'golden',
#  387: 'good',
#  388: 'google',
#  389: 'got',
#  390: 'grated',
#  391: 'great',
#  392: 'green',
#  393: 'grill',
#  394: 'grilled',
#  395: 'ground',
#  396: 'group',
#  397: 'guide',
#  398: 'guy',
#  399: 'hair',
#  400: 'half',
#  401: 'hand',
#  402: 'hands',
#  403: 'happy',
#  404: 'hard',
#  405: 'having',
#  406: 'head',
#  407: 'health',
#  408: 'healthy',
#  409: 'heart',
#  410: 'heat',
#  411: 'heavy',
#  412: 'height',
#  413: 'help',
#  414: 'helps',
#  415: 'herbs',
#  416: 'high',
#  417: 'history',
#  418: 'hit',
#  419: 'hold',
#  420: 'holiday',
#  421: 'home',
#  422: 'homemade',
#  423: 'honey',
#  424: 'hope',
#  425: 'hot',
#  426: 'hour',
#  427: 'hours',
#  428: 'house',
#  429: 'href',
#  430: 'http',
#  431: 'huge',
#  432: 'human',
#  433: 'ice',
#  434: 'idea',
#  435: 'ideas',
#  436: 'image',
#  437: 'images',
#  438: 'immediately',
#  439: 'important',
#  440: 'improve',
#  441: 'inch',
#  442: 'inches',
#  443: 'include',
#  444: 'including',
#  445: 'increase',
#  446: 'industry',
#  447: 'information',
#  448: 'ingredients',
#  449: 'inside',
#  450: 'inspired',
#  451: 'instead',
#  452: 'instructions',
#  453: 'interesting',
#  454: 'international',
#  455: 'internet',
#  456: 'iphone',
#  457: 'isn',
#  458: 'issue',
#  459: 'italian',
#  460: 'items',
#  461: 'january',
#  462: 'job',
#  463: 'jpg',
#  464: 'juice',
#  465: 'july',
#  466: 'june',
#  467: 'just',
#  468: 'key',
#  469: 'kids',
#  470: 'kind',
#  471: 'kitchen',
#  472: 'knew',
#  473: 'knife',
#  474: 'know',
#  475: 'known',
#  476: 'la',
#  477: 'large',
#  478: 'later',
#  479: 'latest',
#  480: 'layer',
#  481: 'lead',
#  482: 'learn',
#  483: 'leave',
#  484: 'leaves',
#  485: 'left',
#  486: 'lemon',
#  487: 'let',
#  488: 'level',
#  489: 'levels',
#  490: 'life',
#  491: 'light',
#  492: 'lightly',
#  493: 'like',
#  494: 'likely',
#  495: 'lime',
#  496: 'line',
#  497: 'link',
#  498: 'liquid',
#  499: 'list',
#  500: 'little',
#  501: 'live',
#  502: 'living',
#  503: 'll',
#  504: 'local',
#  505: 'london',
#  506: 'long',
#  507: 'longer',
#  508: 'look',
#  509: 'looking',
#  510: 'looks',
#  511: 'lose',
#  512: 'loss',
#  513: 'lost',
#  514: 'lot',
#  515: 'lots',
#  516: 'love',
#  517: 'low',
#  518: 'lower',
#  519: 'lunch',
#  520: 'magazine',
#  521: 'main',
#  522: 'major',
#  523: 'make',
#  524: 'makes',
#  525: 'making',
#  526: 'man',
#  527: 'march',
#  528: 'market',
#  529: 'matter',
#  530: 'maybe',
#  531: 'meal',
#  532: 'meals',
#  533: 'mean',
#  534: 'means',
#  535: 'meat',
#  536: 'media',
#  537: 'medical',
#  538: 'medicine',
#  539: 'medium',
#  540: 'melt',
#  541: 'melted',
#  542: 'memory',
#  543: 'men',
#  544: 'method',
#  545: 'microwave',
#  546: 'middle',
#  547: 'milk',
#  548: 'million',
#  549: 'mind',
#  550: 'mini',
#  551: 'minute',
#  552: 'minutes',
#  553: 'mix',
#  554: 'mixed',
#  555: 'mixer',
#  556: 'mixing',
#  557: 'mixture',
#  558: 'model',
#  559: 'models',
#  560: 'mom',
#  561: 'moment',
#  562: 'money',
#  563: 'month',
#  564: 'months',
#  565: 'morning',
#  566: 'mother',
#  567: 'mouth',
#  568: 'muffin',
#  569: 'muscle',
#  570: 'muscles',
#  571: 'mushrooms',
#  572: 'music',
#  573: 'national',
#  574: 'natural',
#  575: 'need',
#  576: 'needed',
#  577: 'needs',
#  578: 'network',
#  579: 'new',
#  580: 'news',
#  581: 'nfl',
#  582: 'nice',
#  583: 'night',
#  584: 'non',
#  585: 'normal',
#  586: 'note',
#  587: 'november',
#  588: 'number',
#  589: 'nutella',
#  590: 'nutrition',
#  591: 'nuts',
#  592: 'october',
#  593: 'offer',
#  594: 'offers',
#  595: 'office',
#  596: 'oh',
#  597: 'oil',
#  598: 'old',
#  599: 'olive',
#  600: 'olympic',
#  601: 'olympics',
#  602: 'ones',
#  603: 'onion',
#  604: 'onions',
#  605: 'online',
#  606: 'open',
#  607: 'optional',
#  608: 'orange',
#  609: 'order',
#  610: 'organic',
#  611: 'original',
#  612: 'ounces',
#  613: 'outside',
#  614: 'oven',
#  615: 'oz',
#  616: 'package',
#  617: 'page',
#  618: 'pain',
#  619: 'pan',
#  620: 'paper',
#  621: 'parchment',
#  622: 'parents',
#  623: 'parmesan',
#  624: 'party',
#  625: 'past',
#  626: 'pasta',
#  627: 'pastry',
#  628: 'peanut',
#  629: 'people',
#  630: 'pepper',
#  631: 'peppers',
#  632: 'percent',
#  633: 'perfect',
#  634: 'person',
#  635: 'personal',
#  636: 'phone',
#  637: 'photo',
#  638: 'photography',
#  639: 'photos',
#  640: 'physical',
#  641: 'pick',
#  642: 'picture',
#  643: 'pictures',
#  644: 'pie',
#  645: 'piece',
#  646: 'pieces',
#  647: 'pink',
#  648: 'pizza',
#  649: 'place',
#  650: 'plan',
#  651: 'plastic',
#  652: 'plate',
#  653: 'play',
#  654: 'player',
#  655: 'plus',
#  656: 'pm',
#  657: 'point',
#  658: 'police',
#  659: 'pop',
#  660: 'popular',
#  661: 'pork',
#  662: 'position',
#  663: 'possible',
#  664: 'post',
#  665: 'posted',
#  666: 'posts',
#  667: 'pot',
#  668: 'potato',
#  669: 'potatoes',
#  670: 'pound',
#  671: 'pounds',
#  672: 'pour',
#  673: 'powder',
#  674: 'powdered',
#  675: 'power',
#  676: 'preheat',
#  677: 'prepare',
#  678: 'prepared',
#  679: 'press',
#  680: 'pressure',
#  681: 'pretty',
#  682: 'prevent',
#  683: 'print',
#  684: 'probably',
#  685: 'problem',
#  686: 'problems',
#  687: 'process',
#  688: 'processor',
#  689: 'produce',
#  690: 'product',
#  691: 'products',
#  692: 'program',
#  693: 'project',
#  694: 'protein',
#  695: 'provide',
#  696: 'public',
#  697: 'published',
#  698: 'pull',
#  699: 'pumpkin',
#  700: 'purpose',
#  701: 'quality',
#  702: 'question',
#  703: 'quick',
#  704: 'quickly',
#  705: 'quite',
#  706: 'rack',
#  707: 'raw',
#  708: 'read',
#  709: 'reading',
#  710: 'ready',
#  711: 'real',
#  712: 'really',
#  713: 'reason',
#  714: 'recent',
#  715: 'recently',
#  716: 'recipe',
#  717: 'recipes',
#  718: 'red',
#  719: 'reduce',
#  720: 'refrigerator',
#  721: 'regular',
#  722: 'related',
#  723: 'remaining',
#  724: 'remember',
#  725: 'remove',
#  726: 'repeat',
#  727: 'report',
#  728: 'research',
#  729: 'researchers',
#  730: 'rest',
#  731: 'restaurant',
#  732: 'result',
#  733: 'results',
#  734: 'return',
#  735: 'review',
#  736: 'rice',
#  737: 'rich',
#  738: 'right',
#  739: 'rise',
#  740: 'risk',
#  741: 'roasted',
#  742: 'roll',
#  743: 'rolls',
#  744: 'room',
#  745: 'round',
#  746: 'run',
#  747: 'running',
#  748: 'safe',
#  749: 'said',
#  750: 'salad',
#  751: 'salt',
#  752: 'san',
#  753: 'sandwich',
#  754: 'sauce',
#  755: 'saucepan',
#  756: 'save',
#  757: 'saw',
#  758: 'say',
#  759: 'says',
#  760: 'school',
#  761: 'science',
#  762: 'search',
#  763: 'season',
#  764: 'second',
#  765: 'seconds',
#  766: 'seeds',
#  767: 'seen',
#  768: 'self',
#  769: 'september',
#  770: 'serve',
#  771: 'served',
#  772: 'serving',
#  773: 'set',
#  774: 'sex',
#  775: 'shape',
#  776: 'share',
#  777: 'sheet',
#  778: 'shoes',
#  779: 'shop',
#  780: 'short',
#  781: 'shows',
#  782: 'shredded',
#  783: 'shrimp',
#  784: 'si',
#  785: 'sides',
#  786: 'sign',
#  787: 'similar',
#  788: 'simmer',
#  789: 'simple',
#  790: 'simply',
#  791: 'single',
#  792: 'sit',
#  793: 'site',
#  794: 'size',
#  795: 'skillet',
#  796: 'skin',
#  797: 'sleep',
#  798: 'slice',
#  799: 'sliced',
#  800: 'slices',
#  801: 'slightly',
#  802: 'slow',
#  803: 'slowly',
#  804: 'small',
#  805: 'smooth',
#  806: 'snack',
#  807: 'social',
#  808: 'soda',
#  809: 'soft',
#  810: 'soon',
#  811: 'soup',
#  812: 'sour',
#  813: 'source',
#  814: 'space',
#  815: 'special',
#  816: 'speed',
#  817: 'spend',
#  818: 'spice',
#  819: 'spinach',
#  820: 'spoon',
#  821: 'sport',
#  822: 'sports',
#  823: 'spray',
#  824: 'spread',
#  825: 'spring',
#  826: 'sprinkle',
#  827: 'stand',
#  828: 'star',
#  829: 'start',
#  830: 'started',
#  831: 'starting',
#  832: 'state',
#  833: 'states',
#  834: 'static',
#  835: 'stay',
#  836: 'steak',
#  837: 'step',
#  838: 'stick',
#  839: 'stir',
#  840: 'stirring',
#  841: 'stop',
#  842: 'store',
#  843: 'story',
#  844: 'straight',
#  845: 'strawberries',
#  846: 'strawberry',
#  847: 'street',
#  848: 'stress',
#  849: 'strong',
#  850: 'studies',
#  851: 'study',
#  852: 'stuff',
#  853: 'style',
#  854: 'sugar',
#  855: 'summer',
#  856: 'sun',
#  857: 'super',
#  858: 'support',
#  859: 'sure',
#  860: 'surface',
#  861: 'sweet',
#  862: 'swimsuit',
#  863: 'syrup',
#  864: 'table',
#  865: 'tablespoon',
#  866: 'tablespoons',
#  867: 'taken',
#  868: 'takes',
#  869: 'taking',
#  870: 'talk',
#  871: 'taste',
#  872: 'tasty',
#  873: 'tbsp',
#  874: 'tea',
#  875: 'team',
#  876: 'teaspoon',
#  877: 'teaspoons',
#  878: 'tech',
#  879: 'technology',
#  880: 'tell',
#  881: 'temperature',
#  882: 'tender',
#  883: 'term',
#  884: 'test',
#  885: 'text',
#  886: 'texture',
#  887: 'thank',
#  888: 'thanks',
#  889: 'thing',
#  890: 'things',
#  891: 'think',
#  892: 'thinking',
#  893: 'thought',
#  894: 'throw',
#  895: 'time',
#  896: 'times',
#  897: 'tip',
#  898: 'tips',
#  899: 'today',
#  900: 'told',
#  901: 'tomato',
#  902: 'tomatoes',
#  903: 'took',
#  904: 'topping',
#  905: 'toss',
#  906: 'total',
#  907: 'touch',
#  908: 'track',
#  909: 'traditional',
#  910: 'training',
#  911: 'transfer',
#  912: 'treat',
#  913: 'treatment',
#  914: 'tried',
#  915: 'true',
#  916: 'try',
#  917: 'trying',
#  918: 'tsp',
#  919: 'turkey',
#  920: 'turn',
#  921: 'turned',
#  922: 'tv',
#  923: 'twitter',
#  924: 'type',
#  925: 'types',
#  926: 'united',
#  927: 'university',
#  928: 'unsalted',
#  929: 'url',
#  930: 'use',
#  931: 'used',
#  932: 'user',
#  933: 'username',
#  934: 'users',
#  935: 'uses',
#  936: 'using',
#  937: 'usually',
#  938: 'vanilla',
#  939: 'var',
#  940: 'variety',
#  941: 've',
#  942: 'vegan',
#  943: 'vegetable',
#  944: 'vegetables',
#  945: 'vegetarian',
#  946: 'version',
#  947: 'video',
#  948: 'videos',
#  949: 'view',
#  950: 'vinegar',
#  951: 'vitamin',
#  952: 'wait',
#  953: 'want',
#  954: 'wanted',
#  955: 'warm',
#  956: 'wasn',
#  957: 'watch',
#  958: 'water',
#  959: 'way',
#  960: 'ways',
#  961: 'wear',
#  962: 'web',
#  963: 'website',
#  964: 'week',
#  965: 'weeks',
#  966: 'weight',
#  967: 'went',
#  968: 'wheat',
#  969: 'whipped',
#  970: 'whisk',
#  971: 'white',
#  972: 'whites',
#  973: 'wide',
#  974: 'width',
#  975: 'win',
#  976: 'wine',
#  977: 'winter',
#  978: 'woman',
#  979: 'women',
#  980: 'won',
#  981: 'wonderful',
#  982: 'words',
#  983: 'work',
#  984: 'working',
#  985: 'workout',
#  986: 'works',
#  987: 'world',
#  988: 'worth',
#  989: 'wrap',
#  990: 'wrong',
#  991: 'www',
#  992: 'year',
#  993: 'years',
#  994: 'yeast',
#  995: 'yellow',
#  996: 'yes',
#  997: 'yogurt',
#  998: 'york',
#  999: 'young'}

# %%
from gensim.models.ldamodel import LdaModel 
from gensim.matutils import Sparse2Corpus 
 
# First we convert our word-matrix into gensim's format  
corpus = Sparse2Corpus(X, documents_columns = False)   

# Then we fit an LDA model 
lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=15)

# %%
print (corpus)
# Out:
# <gensim.matutils.Sparse2Corpus object at 0x10ec92e80>

# %%
num_topics = 15
num_words_per_topic = 5  #trying to print the 5 words that have the highest probability
for ti, topic in enumerate(lda_model.show_topics(num_topics = num_topics, num_words = num_words_per_topic)):
    print("Topic: %d" % (ti))
    print (topic)
    print()
# Out:
# Topic: 0
# (0, '0.085*"com" + 0.061*"http" + 0.058*"www" + 0.038*"online" + 0.034*"sports"')
#
# Topic: 1
# (1, '0.016*"add" + 0.015*"minutes" + 0.015*"cup" + 0.013*"cheese" + 0.011*"salt"')
#
# Topic: 2
# (2, '0.017*"just" + 0.014*"like" + 0.012*"bacon" + 0.012*"time" + 0.011*"make"')
#
# Topic: 3
# (3, '0.027*"chocolate" + 0.021*"cup" + 0.018*"butter" + 0.016*"sugar" + 0.014*"cake"')
#
# Topic: 4
# (4, '0.029*"dress" + 0.020*"style" + 0.020*"hair" + 0.012*"hot" + 0.012*"like"')
#
# Topic: 5
# (5, '0.016*"people" + 0.015*"sleep" + 0.013*"best" + 0.012*"health" + 0.012*"time"')
#
# Topic: 6
# (6, '0.017*"like" + 0.015*"just" + 0.010*"potato" + 0.009*"salad" + 0.009*"oil"')
#
# Topic: 7
# (7, '0.014*"new" + 0.010*"people" + 0.009*"use" + 0.009*"technology" + 0.009*"time"')
#
# Topic: 8
# (8, '0.031*"chicken" + 0.025*"rice" + 0.018*"water" + 0.017*"oil" + 0.013*"cup"')
#
# Topic: 9
# (9, '0.030*"fashion" + 0.012*"new" + 0.012*"clothing" + 0.011*"look" + 0.011*"images"')
#
# Topic: 10
# (10, '0.029*"dough" + 0.013*"oven" + 0.013*"flour" + 0.013*"make" + 0.012*"like"')
#
# Topic: 11
# (11, '0.033*"flashvars" + 0.019*"2011" + 0.015*"image" + 0.014*"static" + 0.014*"game"')
#
# Topic: 12
# (12, '0.044*"food" + 0.027*"raw" + 0.023*"foods" + 0.019*"calories" + 0.017*"fat"')
#
# Topic: 13
# (13, '0.016*"2009" + 0.013*"10" + 0.012*"health" + 0.012*"said" + 0.012*"12"')
#
# Topic: 14
# (14, '0.047*"recipe" + 0.045*"recipes" + 0.015*"bread" + 0.013*"make" + 0.012*"cheese"')

# %%
from gensim.models.word2vec import Word2Vec

# Setup the body text 
text = data.body.dropna().map(lambda x: x.split()) 
model = Word2Vec(text, size=100, window=5, min_count=5, workers=4) #size is the numbe of dimensions of the vector

# %%
model.most_similar(positive=['America'])
# Out:
# [('Japan', 0.8422989845275879),
#  ('North', 0.8382548093795776),
#  ('Australia', 0.8322509527206421),
#  ('South', 0.8309904336929321),
#  ('England', 0.8299078941345215),
#  ('France', 0.8266271948814392),
#  ('Europe', 0.8250114321708679),
#  ('China', 0.8200198411941528),
#  ('Britain', 0.8133131265640259),
#  ('California', 0.8123197555541992)]

# %%
# Unicode Handling
from __future__ import unicode_literals
import codecs

import numpy as np
import gensim

# spacy is used for pre-processing and traditional NLP
import spacy
from spacy.en import English

# Gensim is used for LDA and word2vec
from gensim.models.word2vec import Word2Vec

# %%
# Loading the tweet data
filename = '../dataset/captured-tweets.txt'
tweets = []
for tweet in codecs.open(filename, 'r', encoding="utf-8"):
    tweets.append(tweet)
# Setting up spacy
nlp_toolkit = English()

# %%
tweet_df = pd.DataFrame({'tweet': tweets})
tweet_df.head()
# Out:
#                                                tweet
# 0  I made a(n) Small Tourmaline in Paradise Islan...
# 1  RT @PURELOVEBEAST: -เช็ครายละเอียด- 27th BIRTH...
# 2                          https://t.co/EOfBdVQUfO\n
# 3                      @ViGiGu google it :) simple\n
# 4           nerd ass girl  https://t.co/T7kDirxPEL\n

# %% [markdown]
# ## Exercise 1a
#
# Write a function that can take a take a sentence parsed by `spacy` and identify if it mentions a company named 'Google'. Remember, `spacy` can find entities and codes them as `ORG` if they are a company. Look at the slides for class 13 if you need a hint:
#
# ### Bonus (1b)
#
# Parameterize the company name so that the function works for any company.

# %%
def mentions_company(parsed):
    parsed = nlp_toolkit(parsed)
    
    # Return True if the sentence contains an organization and that organization is Google
#     if(any([word.ent_type_ == 'ORG' for word in parsed])):

    if any([str(word)=='Google' for word in parsed]):
            return True
    return False

# 1b

def mentions_company(parsed, company='Google'):
#     Your code here
    parsed = nlp_toolkit(parsed)
    if any([str(word)==company for word in parsed]):
            return True
    return False
print (tweet_df[tweet_df.tweet.map(lambda x: mentions_company(x, 'Google'))].head())
# Out:
#                                                 tweet
# 8                        Google Play Gift Card Code\n
# 9   Claim your Google Play Gift Card Code... https...
# 13  King of dark fantasy. Summon today. App Store:...
# 14  King of dark fantasy. Summon today. App Store:...
# 16  I've entered to win a Google Nexus 6P from  ! ...

# %% [markdown]
# ## Exercise 1c
#
# Write a function that can take a sentence parsed by `spacy`
# and return the verbs of the sentence (preferably lemmatized)

# %%
def get_actions(parsed):
    actions = []
    # Your code here
    return actions

# %% [markdown]
# ## Exercise 1d
# For each tweet, parse it using spacy and print it out if the tweet has 'release' or 'announce' as a verb. You'll need to use your `mentions_company` and `get_actions` functions.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    if any([str(word)=='Google' for word in parsed]):
        if any([((word.lemma_ == 'release') or (word.lemma_== 'announce')) for word in parsed]):
            print (tweet, "\n")
# Out:
# Google &amp; Ford rumored to announce partnership at CES https://t.co/zOgm1NjHhD https://t.co/Gzx81ujqVC
#
#
# Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/Qvmc34T5QA
#
#
# Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/GNmL0uw9xl
#
#
# Google's Project Ara Spiral is expected to be released next year January https://t.co/prycPMuGsG
#
#
# #Lenovo And #Google To Officially Announce #ProjectTango On January 7 At CES https://t.co/04seCBKv16
#
#
# RT @GizmoChina: Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/GNmL0uw9xl
#
#
# Google and Ford to announce partnership on self-driving cars at CES - Fudzilla (blog) https://t.co/6woe56G22Q
#
#
# Google and Ford to announce partnership on self-driving cars at CES - Fudzilla (blog) https://t.co/4hERVJ4zZK
#
#
# Redesigned Google Glass published on FCC website: release date, Price and features - Tampa Bay Review https://t.co/Vdwr4afx3E www.GlassRoo…

# %% [markdown]
# ## Exercise 1e
# Write a function that identifies countries - HINT: the entity label for countries is GPE (or GeoPolitical Entity)

# %%
def mentions_country(parsed, country):
    pass

# %% [markdown]
# ## Exercise 1f
#
# Re-run (d) to find country tweets that discuss 'Iran' announcing or releasing.

# %%
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    if any([str(word)=='Iran' for word in parsed]):
        if any([((word.lemma_ == 'release') or (word.lemma_== 'announce')) for word in parsed]):
            print (tweet, "\n")
# Out:
# RT @nazirumikailu: Iran pressures Nigeria, demands the release of top Shia leader Ibrahim El-Zakzaky https://t.co/z5vVXQyxLN #BBCAfricaLive
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/TRshnC6sVU
#
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/SlvcQtk3vE
#
#
# RT @Vatescorp: #Sudan: Ministry of Foreign Affairs announced Khartoum has decided to sever diplomatic ties with #Iran https://t.co/ofQG8gtL…
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# Hhmmm. Iran claiming to have 'warned Nigeria' to release detained Shiite leader.... @afalli
#
#
# RT @KenGardner11: Arab allies are breaking diplomatic relations with Iran. Obama's response? Release $100 billion to Iran. The quintessenti…
#
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont…
#
#
# RT @NEWS957: Saudi Arabia announces it is severing ties with Iran, Canada urging diplomacy https://t.co/7JE6dOHoQV
#
#
# Saudi Arabia Just Announced It Plans On Severing Ties With Iran after a Tumultuous Weekend https://t.co/ERj1bScAn5 via @ijdotcom
#
#
# RT @ahmed: Full transcript of press conference where Saudi FM @AdelAljubeir announced cutting diplomatic relations with Iran https://t.co/L…
#
#
# RT @Ebuka_Mbanefo: We have warned Nigeria to release ZakZaky - Islamic Republic Of Iran - https://t.co/7oBA1G4sYH

# %% [markdown]
# ## Exercise 2
# Build a `word2vec` model of the tweets we have collected using `gensim`.
#
# ### Exercise 2a:
# First take the collection of tweets and tokenize them using spacy.
#
# * Think about how this should be done.
# * Should you only use upper-case or lower-case?
# * Should you remove punctuations or symbols?

# %%
text_split = [[x.text if x.pos != spacy.parts_of_speech.VERB else x.lemma_ 
                for x in nlp_toolkit(t)] for t in tweets]

# %%
text_split
# Out:
# [['I',
#   'make',
#   'a(n',
#   ')',
#   'Small',
#   'Tourmaline',
#   'in',
#   'Paradise',
#   'Island',
#   '!',
#   'https://t.co/cAoW1b6DRc',
#   '#',
#   'Gameinsight',
#   '#',
#   'Androidgames',
#   '#',
#   'Android',
#   '\n'],
#  ['RT',
#   '@PURELOVEBEAST',
#   ':',
#   '-เช็ครายละเอียด-',
#   '27th',
#   'BIRTHDAY',
#   'SPECIAL',
#   'GOODS',
#   '-',
#   '3D',
#   'YOSEOP',
#   'USB',
#   '\n'],
#  ['https://t.co/EOfBdVQUfO', '\n'],
#  ['@ViGiGu', 'google', 'it', ':)', 'simple', '\n'],
#  ['nerd', 'ass', 'girl', ' ', 'https://t.co/T7kDirxPEL', '\n'],
#  ['LeadCorp',
#   'Media',
#   '@leadcorpmedia',
#   '_',
#   ' ',
#   'https://t.co/vRJG9Xnzw8',
#   '\n'],
#  ['RT',
#   'mackdrama1017',
#   ':',
#   'ChieMoney',
#   'use',
#   'google',
#   'and',
#   'learn',
#   'how',
#   'to',
#   '!',
#   '\n'],
#  ['@ShaffieWeru',
#   'Morning',
#   'bro',
#   'here',
#   'be',
#   'my',
#   'new',
#   'video',
#   'i',
#   'ne',
#   'yr',
#   'help',
#   'i',
#   'be',
#   'talented',
#   'bt',
#   'i',
#   'lack',
#   'a',
#   'manager',
#   'bro',
#   'https://t.co/NTs3QM5YU5',
#   '\n'],
#  ['Google', 'Play', 'Gift', 'Card', 'Code', '\n'],
#  ['claim',
#   'your',
#   'Google',
#   'Play',
#   'Gift',
#   'Card',
#   'Code',
#   '...',
#   'https://t.co/ySYH1x5kQl',
#   '#',
#   'amazon',
#   '#',
#   'itunes',
#   '#',
#   'googl',
#   '…',
#   'https://t.co/ayDI4X1FKO',
#   '\n'],
#  ['@rizsrug216',
#   '@tpaquette_IID',
#   'Per',
#   'https://t.co/jTlhLW8Ry5',
#   '(',
#   'sorry',
#   ')',
#   ',',
#   'St.',
#   'Devs',
#   'for',
#   'the',
#   'sport',
#   'come',
#   'to',
#   ':',
#   '\n'],
#  ['Baseball', ':', '.039', '\n'],
#  ['Football', ':', '.125', '\n'],
#  ['King',
#   'of',
#   'dark',
#   'fantasy',
#   '.',
#   'Summon',
#   'today',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/XeEuOEaXEG',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/vYQdbhrNEb',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['King',
#   'of',
#   'dark',
#   'fantasy',
#   '.',
#   'Summon',
#   'today',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/1ce13KchYS',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/IkkkXuEu9Q',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['@PolitiBunny',
#   '@PhillipJHill89',
#   'you',
#   'should',
#   'go',
#   'read',
#   'a',
#   'publish',
#   'article',
#   'that',
#   'Russell',
#   'Simmons',
#   'write',
#   'him',
#   'google',
#   'it',
#   '\n'],
#  ['I',
#   'have',
#   'enter',
#   'to',
#   'win',
#   'a',
#   'Google',
#   'Nexus',
#   '6P',
#   'from',
#   ' ',
#   '!',
#   '   ',
#   'https://t.co/4vFHfhaBey',
#   '\n'],
#  ['@moniimamz',
#   'I',
#   'know',
#   '!',
#   'I',
#   'see',
#   'it',
#   'online',
#   'like',
#   'if',
#   'u',
#   'google',
#   'the',
#   'reviews',
#   'for',
#   'it',
#   '!',
#   '😐',
#   '\n'],
#  ['RT',
#   '@kamcb29',
#   ':',
#   'I',
#   'have',
#   'enter',
#   'to',
#   'win',
#   'a',
#   'Google',
#   'Nexus',
#   '6P',
#   'from',
#   '@MakeUseOf',
#   '!',
#   'https://t.co/o30B9xG6Dx',
#   '#',
#   'giveaway',
#   '#',
#   'competition',
#   '\n'],
#  ['Yayyyyy', 'thanks', 'for', 'the', 'follow', '@YeahhImAFangirl', '\n'],
#  ['I',
#   'love',
#   'your',
#   'Google',
#   'plus',
#   'page',
#   'with',
#   'the',
#   'other',
#   'girls',
#   '!',
#   '💜😆',
#   '\n'],
#  ['After',
#   'I',
#   'have',
#   'Google',
#   '&',
#   'amp',
#   ';',
#   'read',
#   'a',
#   'ton',
#   'of',
#   'articles',
#   'on',
#   'the',
#   'same',
#   'subject',
#   ',',
#   'I',
#   'remember',
#   ',',
#   'I',
#   'could',
#   'have',
#   'just',
#   'search',
#   'YouTube',
#   'for',
#   'this',
#   'shit',
#   '😠',
#   '\n'],
#  ['Week', '2', 'Power', 'Rankings😈', ':', 'https://t.co/1xfRayMvpX', '\n'],
#  ['RT',
#   '@ShowerThoughtts',
#   ':',
#   'Apple',
#   'have',
#   '"',
#   'air',
#   '"',
#   ',',
#   'Amazon',
#   'have',
#   '"',
#   'Fire',
#   '"',
#   ',',
#   'Google',
#   'have',
#   '"',
#   'earth',
#   '"',
#   ',',
#   'why',
#   'do',
#   "n't",
#   'Microsoft',
#   'have',
#   '"',
#   'water',
#   '"',
#   '?',
#   '\n'],
#  ['-Looks',
#   'up',
#   'on',
#   'Google',
#   "'",
#   'MikexJeremy',
#   "'",
#   'secretly-',
#   '&',
#   'lt;33',
#   ';)',
#   '[',
#   '@FnafSchimdt,@MikeSchmit10,]#SenpaiBot~',
#   '\n'],
#  ['RT',
#   '@_silentbent',
#   '_',
#   ':',
#   'go',
#   'support',
#   '@dadeputy',
#   'single',
#   '"',
#   'It',
#   'be',
#   'Okay',
#   '"',
#   'feat',
#   '@jaesongreen',
#   'on',
#   'iTunes',
#   ',',
#   'Google',
#   '…',
#   'https://t.co/WPc1jwFLs0',
#   '\n'],
#  ['Hi',
#   ',',
#   'checkout',
#   'this',
#   'application',
#   '.',
#   'https://t.co/cpKpnbsTS7',
#   '\n'],
#  ['RT',
#   '@glotevo',
#   ':',
#   'nerd',
#   'ass',
#   'girl',
#   ' ',
#   'https://t.co/T7kDirxPEL',
#   '\n'],
#  ['I',
#   'be',
#   'play',
#   'My',
#   'Singing',
#   'Monsters',
#   '.',
#   'check',
#   'it',
#   'out',
#   '!',
#   'https://t.co/JrWWtmojWC',
#   '\n'],
#  ['Ever',
#   'want',
#   'to',
#   'become',
#   'a',
#   'Google',
#   'Small',
#   'Business',
#   'Advisor',
#   '?',
#   'Now',
#   'you',
#   'can',
#   '!',
#   'https://t.co/fcOkq6srSX',
#   '\n'],
#  ['check',
#   'out',
#   '@GCloudAndroid',
#   '.',
#   'Never',
#   'worry',
#   'about',
#   'lose',
#   'your',
#   '#',
#   'Android',
#   'device',
#   'up',
#   'to',
#   '10',
#   'GB',
#   'Free',
#   'to',
#   'backup',
#   'https://t.co/7eaqZEHAnI',
#   '\n'],
#  ['Top',
#   'Android',
#   'Apps',
#   '(',
#   'without',
#   'all',
#   'the',
#   'games',
#   ')',
#   'reveal',
#   'in',
#   'hide',
#   'Google',
#   'Play',
#   'Store',
#   'link',
#   '-',
#   '…',
#   'https://t.co/7ZSs9MkcLm',
#   '#',
#   'Android',
#   '#',
#   'India',
#   '\n'],
#  ['RT',
#   '@clashbabes',
#   ':',
#   'Th8',
#   '50vs50',
#   '!',
#   'come',
#   'join',
#   'the',
#   'fun',
#   '!',
#   'https://t.co/mFgZlpU9M4',
#   '\n'],
#  ['https://t.co/0ElEQm917Q',
#   'How',
#   'To',
#   'increase',
#   'Blog',
#   'Traffic',
#   'With',
#   'Google',
#   'Plus',
#   '-',
#   '#',
#   'Blogging',
#   '#',
#   'SMM',
#   '#',
#   'SocialMedia',
#   'https://t.co/UIcEYNJ4u2',
#   ':',
#   'OfficialChat',
#   '…',
#   '\n'],
#  ['RelNews', ':', '\n'],
#  ['                    ',
#   'Europe',
#   'could',
#   'produce',
#   'a',
#   'Facebook',
#   "'",
#   'and',
#   'the',
#   'Google',
#   'of',
#   'healthcare',
#   '\n'],
#  [' ', '-The', 'Daily', 'Telegraph-', 'https://t.co/C6J53DKUuU', '\n'],
#  ['RelNews', ':', '\n'],
#  ['                    ',
#   'Europe',
#   'could',
#   'produce',
#   'a',
#   'Facebook',
#   '\\',
#   "'",
#   'and',
#   'the',
#   'Google',
#   'of',
#   'healthcare',
#   '\n'],
#  [' ', '-The', 'Daily', 'Telegraph-', 'https://t.co/C6J53DKUuU', '\n'],
#  ['New',
#   'post',
#   ':',
#   'Google',
#   'Knowledge',
#   'Graph',
#   'Optimization',
#   'Strategies',
#   'for',
#   'the',
#   'New',
#   'Year',
#   'for',
#   'Infographic',
#   'Designers',
#   'https://t.co/qsdAbq3HnD',
#   '\n'],
#  ['Anyone',
#   'else',
#   'spend',
#   'the',
#   'entire',
#   'time',
#   'drive',
#   'try',
#   'to',
#   'beat',
#   'the',
#   'original',
#   'arrival',
#   'time',
#   'estimate',
#   'from',
#   'Google',
#   'Maps',
#   '?',
#   '🙃',
#   '\n'],
#  ['#',
#   'DESIGN',
#   ':',
#   'Font',
#   'of',
#   'the',
#   'day',
#   ':',
#   'Mecka',
#   'https://t.co/9iI2KGZ0ZH',
#   '#',
#   'design',
#   '\n'],
#  ['Google',
#   ',',
#   'you',
#   'have',
#   'fail',
#   'me',
#   'for',
#   'the',
#   'first',
#   'time',
#   '!',
#   'Why',
#   'can',
#   "n't",
#   'you',
#   'tell',
#   'me',
#   'what',
#   'these',
#   'crystals',
#   'be',
#   'inside',
#   'my',
#   'plum',
#   '?',
#   'https://t.co/vXmONcnTom',
#   '\n'],
#  ['RT',
#   '@rougek68',
#   ':',
#   'On',
#   'the',
#   'Meaning',
#   'of',
#   '#',
#   'Fascism',
#   'https://t.co/jfoIA7jcS9',
#   '\n'],
#  ['#', 'USA', '#', 'israel', '\n'],
#  ['We', 'be', 'All', '#', 'Fascists', 'Now', 'https://t.co/NEQYZufaBV', '\n'],
#  ['Time', 'U', 'kno', '…', '\n'],
#  ['Google', '#', 'Team2PM', '\n'],
#  ['RT',
#   '@clashbabes',
#   ':',
#   'Th8',
#   '50vs50',
#   '!',
#   'come',
#   'join',
#   'the',
#   'fun',
#   '!',
#   'https://t.co/mFgZlpU9M4',
#   '\n'],
#  ['The',
#   'first',
#   'time',
#   'someone',
#   'comment',
#   '"',
#   'Schwing',
#   '!',
#   '"',
#   'on',
#   'one',
#   'of',
#   'my',
#   'selfies',
#   ',',
#   'I',
#   'have',
#   'to',
#   'google',
#   'what',
#   'it',
#   'be',
#   '.',
#   'It',
#   'be',
#   'basically',
#   'an',
#   'old',
#   'guy',
#   'compliment',
#   'you',
#   '.',
#   '\n'],
#  ['RT',
#   '@_rachaelmcclung',
#   ':',
#   'Brain',
#   ':',
#   'go',
#   'to',
#   'sleep',
#   'its',
#   '10',
#   'pm',
#   'you',
#   'now',
#   'have',
#   'a',
#   'decent',
#   '8',
#   'hours',
#   'of',
#   'sleep',
#   '..',
#   '\n'],
#  ['Me',
#   ':',
#   'stay',
#   'up',
#   'to',
#   'google',
#   'different',
#   'food',
#   'recipes',
#   'for',
#   '…',
#   '\n'],
#  ['RT',
#   'https://t.co/s2HOfLUV2t',
#   '#',
#   'Google',
#   "'",
#   '#',
#   'Android',
#   'N',
#   "'",
#   'will',
#   'Not',
#   'use',
#   '#',
#   'Oracle',
#   "'s",
#   ' ',
#   '#',
#   'Java',
#   'APIs',
#   ' ',
#   'https://t.co/fBMNzW4wdT',
#   'gunjanraik',
#   '\n'],
#  ['RT',
#   'https://t.co/HqV9jSb6In',
#   'Android',
#   'application',
#   'relate',
#   'to',
#   'google',
#   'maps',
#   '--',
#   '2',
#   'by',
#   'nsatheeshk',
#   ':',
#   'need',
#   'to',
#   'update',
#   'the',
#   'Android',
#   'Mobil',
#   '...',
#   '…',
#   '\n'],
#  ['My',
#   'mini',
#   'just',
#   'go',
#   'to',
#   'th9',
#   '😢',
#   'but',
#   'this',
#   'will',
#   'be',
#   'a',
#   'fun',
#   'event',
#   'for',
#   'any',
#   'th8s',
#   'out',
#   'there',
#   '!',
#   '!',
#   'https://t.co/5w4A07lZDs',
#   '\n'],
#  ['#',
#   'OldRocks',
#   '-',
#   '#',
#   'StructuresLeftBehind',
#   ':',
#   '#',
#   'PreDeluge',
#   'Ancient',
#   '#',
#   'MicroSculpture',
#   'To',
#   'Massive',
#   'Face',
#   '&',
#   'amp',
#   ';',
#   'Shape',
#   '#',
#   'Iconography',
#   'Remain',
#   'https://t.co/nFd2nXEtGh',
#   '\n'],
#  ['@ImbruedJoint',
#   'Hector',
#   'have',
#   'softly',
#   'tilt',
#   'his',
#   'head',
#   'towards',
#   'Stuart',
#   'in',
#   'a',
#   'confused',
#   'sort',
#   'of',
#   'way',
#   '.',
#   '"',
#   'What',
#   'be',
#   'Google',
#   '?',
#   '"',
#   'He',
#   'could',
#   "n't",
#   'possibly',
#   'know',
#   'what',
#   '--',
#   '\n'],
#  ['Good',
#   'domain',
#   'possibility',
#   '?',
#   ':',
#   'www',
#   '.',
#   'West',
#   'Virginia',
#   'https://t.co/xi1QYKRHNt',
#   '?',
#   '?',
#   'Its',
#   'trending',
#   'on',
#   'google',
#   '...',
#   '\n'],
#  ['Here',
#   'man',
#   '@TheRealLogs1996',
#   'when',
#   'you',
#   'talk',
#   'about',
#   'how',
#   'the',
#   'Cubs',
#   'win',
#   'last',
#   'year',
#   ' ',
#   'https://t.co/NGbZGA7DP6',
#   '\n'],
#  ['Google',
#   'Knowledge',
#   'Graph',
#   'Optimization',
#   'Strategies',
#   'for',
#   'the',
#   'New',
#   'Year',
#   'for',
#   'Infographic',
#   '\xa0',
#   'Designers',
#   'https://t.co/wJMnQtv4Rx',
#   'https://t.co/jyIZemYUGH',
#   '\n'],
#  ['LebanonHashtag',
#   ':',
#   'RT',
#   'probrandz',
#   ':',
#   '#',
#   'Facebook',
#   'Open',
#   'Sources',
#   'Artificial',
#   '#',
#   'Intelligence',
#   'Servers',
#   'Before',
#   '#',
#   'Google',
#   '|',
#   'Re',
#   '/',
#   'code',
#   'https://t.co/f8RTJxEzSx',
#   '\n'],
#  ['#', 'di', '…', '\n'],
#  ['@r0thejan',
#   'earn',
#   'free',
#   'Google',
#   'Play',
#   'and',
#   'many',
#   'more',
#   'Giftcards',
#   'at',
#   'our',
#   'fresh',
#   'publish',
#   'Website',
#   'https://t.co/zPQb0lfDs9',
#   'https://t.co/udIaPeF945',
#   '\n'],
#  ['KalGuntuku',
#   ':',
#   'RT',
#   'bunnymiilk',
#   '"',
#   'RT',
#   '30seclovelive',
#   ':',
#   '[',
#   'RT',
#   'to',
#   'win',
#   '!',
#   ']',
#   '30',
#   'Seconds',
#   'of',
#   'Love',
#   'Live',
#   '!',
#   '5k',
#   'Followers',
#   'Giveaway',
#   '#',
#   '1',
#   ':',
#   '$',
#   '25',
#   'iTunes',
#   '/',
#   'Google',
#   'play',
#   'gift',
#   'ca',
#   '…',
#   '\n'],
#  ['RT',
#   '@FortuneMagazine',
#   ':',
#   'Here',
#   '’s',
#   'how',
#   'Google',
#   'be',
#   'take',
#   'on',
#   'Uber',
#   'in',
#   '2016',
#   'https://t.co/X5STl6P5Xh',
#   '\n'],
#  ['[',
#   'Minecraft',
#   ']',
#   'I',
#   'google',
#   '"',
#   'Natural',
#   'arch',
#   '"',
#   'and',
#   'a',
#   'Minecraft',
#   'image',
#   'pop',
#   'up',
#   'for',
#   'a',
#   'real',
#   'geographical',
#   'scenic',
#   'spot',
#   'by',
#   'Skandal',
#   '…',
#   'https://t.co/9ZZrZrfJpP',
#   '\n'],
#  ['shenbrood',
#   ':',
#   'What',
#   'be',
#   'your',
#   'greatest',
#   '#',
#   'digitalmarketing',
#   '#',
#   'contentmarket',
#   'blunder',
#   '?',
#   ' ',
#   'Well',
#   'for',
#   'me',
#   'it',
#   'be',
#   'the',
#   'ever',
#   'change',
#   'Google',
#   'algorith',
#   '.',
#   ' ',
#   'What',
#   'abo',
#   '…',
#   '\n'],
#  ['https://t.co/tkiiygFXRd',
#   'What',
#   'each',
#   'state',
#   '#',
#   'Google',
#   'd',
#   'more',
#   'than',
#   '...',
#   '#',
#   'me',
#   '#',
#   'love',
#   '#',
#   'picoftheday',
#   '#',
#   'follow',
#   '\n'],
#  ['@hadley_delducaa',
#   'google',
#   'a',
#   'wolf',
#   'hybrid',
#   'its',
#   'my',
#   'future',
#   'dog',
#   '\n'],
#  ['Europe',
#   'could',
#   'produce',
#   'a',
#   'Facebook',
#   '-',
#   'and',
#   'the',
#   'Google',
#   'of',
#   'healthcare',
#   'https://t.co/xEwaWcPRNF',
#   '\n'],
#  ['I',
#   'have',
#   'unlock',
#   'a',
#   'new',
#   'area',
#   'of',
#   'my',
#   'Island',
#   '!',
#   'https://t.co/gmGshSxtLG',
#   '#',
#   'Gameinsight',
#   '#',
#   'Android',
#   '#',
#   'Androidgames',
#   '\n'],
#  ['https://t.co/GVac2xs9OO',
#   'get',
#   'it',
#   ':',
#   'Google',
#   "'s",
#   'latest',
#   'free',
#   'Android',
#   'wallpaper',
#   'show',
#   'useful',
#   'phone',
#   '...',
#   'https://t.co/KdbaKUYglP',
#   '#',
#   'Android',
#   '\n'],
#  ['I',
#   'have',
#   'reach',
#   'level',
#   '28',
#   '.',
#   'I',
#   'earn',
#   '\xa0',
#   '$',
#   '123000',
#   'and',
#   '€',
#   '3',
#   '!',
#   'https://t.co/5qOLKlLp9K',
#   '#',
#   'Gameinsight',
#   '#',
#   'Androidgames',
#   '#',
#   'Android',
#   '\n'],
#  ['make',
#   'sure',
#   'your',
#   'siwe',
#   'ishkeep',
#   'xsers',
#   'mn',
#   'thxir',
#   'preferred',
#   'ver|ion',
#   ' ',
#   'fkyourmwebsite',
#   'for',
#   'tceir',
#   'entule',
#   'vtsiq',
#   '.',
#   '(',
#   'Google',
#   'Webmcstervkx',
#   '\n'],
#  ['RT',
#   '@ladybirdcoc',
#   ':',
#   'My',
#   'mini',
#   'just',
#   'go',
#   'to',
#   'th9',
#   '😢',
#   'but',
#   'this',
#   'will',
#   'be',
#   'a',
#   'fun',
#   'event',
#   'for',
#   'any',
#   'th8s',
#   'out',
#   'there',
#   '!',
#   '!',
#   'https://t.co/5w4A07lZDs',
#   '\n'],
#  ['#',
#   'NFL',
#   '#',
#   'MarshawnLynch',
#   '2013',
#   '"',
#   'NFC',
#   'Champ',
#   'game',
#   '"',
#   'MARSHAWN',
#   'LYNCH',
#   'Touchdown',
#   'Run',
#   'Seattle',
#   'Seahawks',
#   '8x10',
#   'photo',
#   'https://t.co/tnS1K7aZFS',
#   '#',
#   'Seahawks',
#   '#',
#   'Google',
#   '\n'],
#  ['@chocolateluvah',
#   'completely',
#   'agree',
#   'it',
#   'be',
#   'kill',
#   'me',
#   'not',
#   'to',
#   'google',
#   'the',
#   'case',
#   'haha',
#   '\n'],
#  ['@JedDzn',
#   '@IvanOfficial',
#   '_',
#   '_',
#   '@picardonoel',
#   'what',
#   's',
#   'that',
#   '?',
#   '*',
#   'do',
#   'nt',
#   'ask',
#   'me',
#   'to',
#   'google',
#   'it',
#   '*',
#   '\n'],
#  ['RT',
#   '@seosanjayupadhy',
#   ':',
#   'Alt',
#   '+',
#   '6',
#   '.......',
#   '♠',
#   '.....',
#   's¬pade',
#   'Alt',
#   '+',
#   '5',
#   '.......',
#   '♣',
#   '......',
#   '¬Club',
#   'Alt',
#   '+',
#   '3',
#   '.............',
#   '¬Heart',
#   'Alt',
#   '+',
#   '4',
#   '.......',
#   '♦',
#   '......',
#   '¬Diamond',
#   '…',
#   'htt',
#   '…',
#   '\n'],
#  ['RT',
#   '@chrismessina',
#   ':',
#   'tell',
#   'me',
#   'that',
#   'Zuck',
#   'be',
#   "n't",
#   'plan',
#   'to',
#   'take',
#   'on',
#   'Google',
#   'with',
#   'Messenger',
#   '...',
#   '#',
#   'ConvComm',
#   ' ',
#   'https://t.co/2ludfQPLTl',
#   'https://t.co/8QbN',
#   '…',
#   '\n'],
#  ['second',
#   '.',
#   'When',
#   'I',
#   'be',
#   'tweet',
#   ',',
#   'I',
#   'have',
#   'always',
#   'get',
#   'my',
#   'Google',
#   'Docs',
#   'open',
#   'as',
#   'well',
#   '.',
#   '#',
#   'amwrit',
#   'https://t.co/cIA8OVoKSE',
#   '\n'],
#  ['https://t.co/wiRZHnHUYV',
#   'RT',
#   'ShowerThoughtts',
#   ':',
#   'Apple',
#   'have',
#   '"',
#   'air',
#   '"',
#   ',',
#   'Amazon',
#   'have',
#   '"',
#   'Fire',
#   '"',
#   ',',
#   'Google',
#   'have',
#   '"',
#   'earth',
#   '"',
#   ',',
#   'why',
#   'do',
#   "n't",
#   'M',
#   '…',
#   'https://t.co/O69Q8NpBmK',
#   '\n'],
#  ['@luckyberry96',
#   'go',
#   'to',
#   'this',
#   'website',
#   '.',
#   'https://t.co/4O42egV2MV',
#   'copy',
#   'and',
#   'paste',
#   'it',
#   'in',
#   'twitter',
#   '.',
#   'Tweet',
#   'more',
#   'for',
#   '#',
#   'TeamSeventeen',
#   '\n'],
#  ['@victoria_stee',
#   'u',
#   '+',
#   'google',
#   "'s",
#   'instructions',
#   'just',
#   'save',
#   'my',
#   'life😘',
#   '\n'],
#  ['RT',
#   '@KunalChoudhary',
#   '_',
#   ':',
#   'Pathankot',
#   'attack',
#   ':',
#   'Youth',
#   'Congress',
#   'members',
#   'burn',
#   'Sharifs',
#   'effigy',
#   'in',
#   'Bhopal',
#   'https://t.co/n3uftphdsx',
#   '(',
#   '@IndiaToday',
#   ')',
#   '\n'],
#  ['@RajaBrar', '…', '\n'],
#  ['https://t.co/rbIrlQpYMx',
#   'ALSO',
#   'HERE',
#   'IT',
#   'be',
#   'MY',
#   'REVAMPED',
#   'AND',
#   'MUCH',
#   'BETTER',
#   'GOT7',
#   'PRIMER',
#   'SHARE',
#   'OUR',
#   'BOYS',
#   'WITH',
#   'THE',
#   'WORLD',
#   '\n'],
#  ['I',
#   'have',
#   'enter',
#   'to',
#   'win',
#   'a',
#   'Google',
#   'Nexus',
#   '6P',
#   'from',
#   '@MakeUseOf',
#   '!',
#   'https://t.co/tiM479eSDN',
#   '#',
#   'giveaway',
#   '#',
#   'competition',
#   '\n'],
#  ['New',
#   'Mobile',
#   'Apps',
#   'on',
#   '#',
#   'PlayStore',
#   '#',
#   'Android',
#   ':',
#   'Gods',
#   'Of',
#   'Rome',
#   ',',
#   'cut',
#   'The',
#   'Rope',
#   ',',
#   'Gun',
#   'Simulator',
#   ',',
#   'KitWall',
#   'etc',
#   '.Check',
#   'More',
#   'on',
#   'https://t.co/BszRb7JO4E',
#   '\n'],
#  ['Any', 'other', 'takers', '?', 'https://t.co/J0DhhMF9T4', '\n'],
#  ['GoogleExpertUK',
#   ':',
#   '#',
#   'Google',
#   'support',
#   'Swedish',
#   'Chef',
#   'from',
#   'The',
#   'Muppets',
#   '!',
#   'MuppetsStudio',
#   '#',
#   'internet',
#   '#',
#   '…',
#   'https://t.co/pUrY7IHU4y',
#   ')',
#   'https://t.co/e43mzDlDzw',
#   '\n'],
#  ['ECO',
#   '100',
#   'WK',
#   '10',
#   'CHAPTER',
#   '18',
#   'HOMEWORK',
#   '-',
#   'https://t.co/BURTA5bO3w',
#   '\n'],
#  ['@WinterFNmute665',
#   '@RT_America',
#   'look',
#   'up',
#   'militia',
#   'too',
#   ',',
#   'second',
#   'definition',
#   'on',
#   'google',
#   '.',
#   '\n'],
#  ['do',
#   "n't",
#   'google',
#   'Any',
#   'Of',
#   'These',
#   'Terms',
#   'No',
#   'Matter',
#   'How',
#   'Bad',
#   'You',
#   'want',
#   'To',
#   '!',
#   '...',
#   'https://t.co/vfcd3RHdYM',
#   '\n'],
#  ['KalGuntuku',
#   ':',
#   'RT',
#   'bunnymiilk',
#   '"',
#   'RT',
#   '30seclovelive',
#   ':',
#   '[',
#   'RT',
#   'to',
#   'win',
#   '!',
#   ']',
#   '30',
#   'Seconds',
#   'of',
#   'Love',
#   'Live',
#   '!',
#   '5k',
#   'Followers',
#   'Giveaway',
#   '#',
#   '1',
#   ':',
#   '$',
#   '25',
#   'i',
#   '…',
#   'https://t.co/jtvcWEI0SV',
#   '\n'],
#  ['@ohitsmrcreeper',
#   '@SapphireGinger',
#   'oh',
#   'thank',
#   'god',
#   'google',
#   'translate',
#   'be',
#   'wrong',
#   '\n'],
#  ['RT',
#   '@CarlaLioness',
#   ':',
#   '✔TWEETSHEET➡PETITIONS',
#   '-',
#   'PART',
#   '3✔',
#   'SUPPORT',
#   'THE',
#   'FIGHT',
#   'AGAINST',
#   'DOG&amp;CAT',
#   '#',
#   'MEATINDUSTRY',
#   'IN',
#   '#',
#   'SouthKorea',
#   'https://t.co/TKildjZJNr',
#   'http',
#   '…',
#   '\n'],
#  ['Google', 'Maps', 'https://t.co/dU4PD1ch4V', '\n'],
#  ['@Xen_Games',
#   'Google',
#   'do',
#   "n't",
#   'say',
#   'what',
#   '5',
#   'out',
#   '7',
#   'mean',
#   'why',
#   'not',
#   '7',
#   'out',
#   'of',
#   '7',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   '\n'],
#  ['@MakingStarWars',
#   'Ugh',
#   '.',
#   'The',
#   'rights',
#   'sign',
#   'mess',
#   'up',
#   'the',
#   'link',
#   '.',
#   'Google',
#   "'",
#   'force',
#   'awaken',
#   '70',
#   'mm',
#   "'",
#   'and',
#   'the',
#   'IMAX',
#   'link',
#   'should',
#   'send',
#   'you',
#   'there',
#   '.',
#   '\n'],
#  ['RT',
#   '@dinowoowife',
#   ':',
#   '[',
#   'MY',
#   ']',
#   'BTS',
#   '2ND',
#   'MUSTER',
#   'SLOGAN',
#   '"',
#   '두근건',
#   '"',
#   'BY',
#   'VISUAL',
#   'shock',
#   '@VShock1230',
#   'https://t.co/SpccZhS5mk',
#   'https://t.co/kOiqxiSZYk',
#   '\n'],
#  ['LebanonHashtag',
#   ':',
#   'RT',
#   'probrandz',
#   ':',
#   '#',
#   'Facebook',
#   'Open',
#   'Sources',
#   'Artificial',
#   '#',
#   'Intelligence',
#   'Servers',
#   'Before',
#   '#',
#   'Google',
#   '|',
#   'Re',
#   '/',
#   'code',
#   'https://t.co/VgWBxAG52q',
#   '\n'],
#  ['#', 'di', '…', '\n'],
#  ['RT',
#   '@TheMoneyGenie',
#   ':',
#   'Why',
#   'PayPal',
#   '.',
#   'Me',
#   'be',
#   'So',
#   'Infuriating',
#   '(',
#   'But',
#   'I',
#   'be',
#   'use',
#   'It',
#   'Anyway',
#   ')',
#   ' ',
#   'work',
#   'from',
#   'home',
#   'https://t.co/JeP3833l2i',
#   'https://t.co/RFJhUsiy7Z',
#   '\n'],
#  ['Ford',
#   'add',
#   'Apple',
#   'CarPlay',
#   'and',
#   'Android',
#   'Auto',
#   'to',
#   'Sync',
#   '3',
#   ',',
#   '...',
#   'https://t.co/NSPCS9KHWE',
#   '#',
#   'google',
#   '|',
#   'https://t.co/MZBQSll3dP',
#   'https://t.co/tHKibTMDlU',
#   '\n'],
#  ['Best', 'colour', 'for', 'zodiac', 'sign', 'in', 'year', '2016', '\n'],
#  ['https://t.co/WHqjhaywhq', '\n'],
#  ['@ShaffieWeru',
#   'hi',
#   'bro',
#   'i',
#   'ne',
#   'your',
#   'help',
#   'here',
#   'be',
#   'my',
#   'new',
#   'video',
#   '..',
#   'can',
#   'you',
#   'manage',
#   'me',
#   'bro',
#   'https://t.co/NTs3QM5YU5',
#   '\n'],
#  ['try',
#   'TwitGrow',
#   'for',
#   'Twitter',
#   '!',
#   'get',
#   '1000',
#   '+',
#   'REAL',
#   'followers',
#   ',',
#   'retweets',
#   'and',
#   'favorites',
#   '!',
#   'Google',
#   'Play',
#   ':',
#   'https://t.co/v5qI6nbcZt',
#   'https://t.co/s5wKVVeiCI',
#   '\n'],
#  ['RT',
#   '@lw',
#   ':',
#   'How',
#   'To',
#   'be',
#   'The',
#   'Person',
#   'Who',
#   'Never',
#   'miss',
#   'A',
#   'Deadline',
#   'https://t.co/jxsYcQpjII',
#   '\n'],
#  ['shenbrood',
#   ':',
#   'What',
#   'be',
#   'your',
#   'greatest',
#   '#',
#   'digitalmarketing',
#   '#',
#   'contentmarket',
#   'blunder',
#   '?',
#   ' ',
#   'Well',
#   'for',
#   'me',
#   'it',
#   'be',
#   'the',
#   'ever',
#   'change',
#   'Google',
#   'algorith',
#   '.',
#   ' ',
#   'What',
#   'abo',
#   '…',
#   '\n'],
#  ['RT',
#   '@dinowoowife',
#   ':',
#   '[',
#   'MY',
#   ']',
#   'JIMIN',
#   '2016',
#   "'",
#   'RISE',
#   "'",
#   'stock',
#   'sale',
#   'by',
#   'MINingful',
#   'moment',
#   '@miningfulmoment',
#   '♥',
#   'https://t.co/DwRaGK45D3',
#   'https://t.co/Nh04n1sB5b',
#   '\n'],
#  ['#',
#   'creativitybooster',
#   ':',
#   'Communicate',
#   'stupid',
#   'affiliate',
#   'at',
#   'Google',
#   '.',
#   'TOP',
#   '10',
#   'ideas',
#   ':',
#   'https://t.co/9Dww7xv6t2',
#   '#',
#   'growthhacking',
#   '#',
#   'blogg',
#   '\n'],
#  ['#',
#   'RADIO',
#   '#',
#   'TOP40',
#   'Now',
#   'play',
#   '#',
#   'shut',
#   'Up',
#   '#',
#   'Stormzy',
#   '#',
#   'APPS',
#   'Apple',
#   'https://t.co/GIrJLsb5lM',
#   'Google',
#   'https://t.co/P24euDWBeU',
#   '\n'],
#  ['will',
#   'Google',
#   'do',
#   'one',
#   'of',
#   'those',
#   'semantically',
#   '-',
#   'aware',
#   'auto',
#   '-',
#   'answers',
#   'if',
#   'I',
#   'search',
#   '"',
#   'RZA',
#   'Elo',
#   '"',
#   '?',
#   'do',
#   "n't",
#   'wanna',
#   'be',
#   'disappointed',
#   '\n'],
#  ['Just',
#   'like',
#   'new',
#   'college',
#   'students',
#   'be',
#   'at',
#   'risk',
#   'for',
#   'the',
#   'Freshman',
#   '15',
#   ',',
#   'Google',
#   'employees',
#   'joke',
#   'about',
#   'the',
#   'Google',
#   '15',
#   'from',
#   'all',
#   'the',
#   'snaks',
#   'available',
#   '.',
#   '\n'],
#  ['Me', 'af', '😂😂😂', 'https://t.co/fUw8UrVIV0', '\n'],
#  ['Spare',
#   'mark',
#   'as',
#   'respect',
#   'the',
#   'google',
#   'android',
#   'scum',
#   'yourself',
#   'april',
#   'au',
#   'pair',
#   'self',
#   ':',
#   'skacV',
#   'https://t.co/mjgyEDMeWw',
#   '\n'],
#  ['Google',
#   '#',
#   'Cardboard',
#   'Used',
#   'By',
#   'Surgeons',
#   'To',
#   'perform',
#   'Heart',
#   'Surgery',
#   'And',
#   'Saves',
#   'A',
#   'Life',
#   'https://t.co/LtMxdRcatV',
#   'https://t.co/Zd6YAFTvUn',
#   '\n'],
#  ['RT',
#   '@TheMoneyGenie',
#   ':',
#   'Why',
#   'spend',
#   'Money',
#   'Saves',
#   'You',
#   'Time',
#   '(',
#   'and',
#   'Earns',
#   'You',
#   'More',
#   'Money',
#   ')',
#   ' ',
#   'work',
#   'from',
#   'home',
#   'https://t.co/4hrngezka4',
#   'https://t.co/2jjwyW',
#   '…',
#   '\n'],
#  ['This',
#   'House',
#   'be',
#   'sell',
#   'Dirt',
#   'Cheap',
#   ',',
#   'The',
#   'Google',
#   'Maps',
#   'Picture',
#   'Explains',
#   'Exactly',
#   'Why',
#   '....',
#   'https://t.co/6yJUWU1o9v',
#   '\n'],
#  ['Google', 'have', 'no', 'chill', 'https://t.co/Rs2QG2NXQa', '\n'],
#  ['RT',
#   '@got7style',
#   ':',
#   '[',
#   '#',
#   'B2GETHER',
#   ']',
#   'GOT7',
#   'with',
#   'B',
#   'Connect',
#   'Bracelet',
#   '\n'],
#  ['#',
#   'JB',
#   ' ',
#   '#',
#   'JACKSON',
#   ' ',
#   '#',
#   'TEAMGOT7',
#   '#',
#   'GOT7STYLE',
#   '\n'],
#  ['https://t.co/VCVVUZfGNU', '…', 'https://t.co/BueT9Zr', '…', '\n'],
#  ['Women',
#   'rise',
#   'in',
#   'HP',
#   'panchayat',
#   'politics',
#   'https://t.co/jo0pJfFB6X',
#   '#',
#   'HP',
#   '\n'],
#  ['Police',
#   'condemn',
#   'Facebook',
#   'comments',
#   'on',
#   'Mount',
#   'Maunganui',
#   'New',
#   'Year',
#   "'s",
#   'Eve',
#   'page',
#   'https://t.co/BaomUZeAw8',
#   '#',
#   'facebook',
#   '\n'],
#  ['wonder',
#   'Which',
#   'Food',
#   'be',
#   'Healthier',
#   'Google',
#   'have',
#   'A',
#   'Tool',
#   'For',
#   '…',
#   ':',
#   'https://t.co/HxOGzZ0Vfr',
#   '...',
#   '\n'],
#  ['RT',
#   '@f396',
#   ':',
#   'Iran',
#   'blame',
#   'America',
#   ',',
#   'Britain',
#   'and',
#   "'",
#   'Zionists',
#   "'",
#   'for',
#   'Nimr',
#   'execution',
#   '-',
#   'https://t.co/BwXEicgAOA',
#   'via',
#   'https://t.co/UjStGmTT2f',
#   '\n'],
#  ['@trp_takumi', '[', 'reply', ']', '\n'],
#  ['\n'],
#  ['Gunakan', 'lah', 'google', 'translate', ',', 'lol', 'xD', '\n'],
#  ['Lifehacker',
#   ':',
#   'run',
#   'Windows',
#   'on',
#   'Your',
#   'Mac',
#   ':',
#   'VirtualBox',
#   'vs',
#   'VMware',
#   'Fusion',
#   'vs',
#   'Parallels',
#   '.',
#   'https://t.co/OZFvvqpkEf',
#   '\n'],
#  ['The',
#   'Polar',
#   'Bears',
#   '-',
#   'Movies',
#   '&',
#   'amp',
#   ';',
#   'TV',
#   'on',
#   'Google',
#   'Play',
#   'https://t.co/wkSSSKkHH6',
#   '\n'],
#  ['"',
#   'become',
#   'a',
#   'Google',
#   'Small',
#   'Business',
#   'Expert',
#   'Advisor',
#   '"',
#   ' ',
#   'https://t.co/8GfXh7JZI8',
#   '#',
#   'inboundmarketing',
#   '#',
#   'feedly',
#   '\n'],
#  ['Gang',
#   'knock',
#   'down',
#   'Cane',
#   'Grove',
#   'man',
#   'then',
#   'beat',
#   'him',
#   'to',
#   'death',
#   'https://t.co/EfTP6JbZS9',
#   '#',
#   'beat',
#   '\n'],
#  ['Ohio',
#   'State',
#   'basketball',
#   'win',
#   'sixth',
#   'straight',
#   ',',
#   'beat',
#   'Illinois',
#   '75',
#   '-',
#   '73',
#   'https://t.co/uSeu3D1Byp',
#   '#',
#   'beat',
#   '\n'],
#  ['RT',
#   '@newsycombinator',
#   ':',
#   'Google',
#   ',',
#   'HP',
#   ',',
#   'Oracle',
#   'Join',
#   'RISC',
#   '-',
#   'V',
#   '–',
#   'Open',
#   '-',
#   'source',
#   'processor',
#   'core',
#   'gains',
#   'traction',
#   'https://t.co/8xnBu3TICr',
#   '\n'],
#  ['@_QueenLioness',
#   '_',
#   '@justinrgrrb',
#   '@McDonald_Wes',
#   'Sweet',
#   'De',
#   '-',
#   'Lights',
#   'Bakery',
#   'Inc',
#   '&',
#   'lt;----',
#   'this',
#   'place',
#   ',',
#   'google',
#   'it',
#   '...',
#   'A++++++',
#   '\n'],
#  ['RT',
#   '@f396',
#   ':',
#   'Saudi',
#   'Arabia',
#   'sever',
#   'diplomatic',
#   'ties',
#   'with',
#   'Iran',
#   'over',
#   'embassy',
#   'fire',
#   '-',
#   'https://t.co/r0iZugJa3v',
#   'via',
#   'https://t.co/UjStGmTT2f',
#   '\n'],
#  ['RT',
#   '@TheMoneyGenie',
#   ':',
#   'Why',
#   'People',
#   'Un',
#   '-',
#   'Follow',
#   'You',
#   'On',
#   'Social',
#   'Media',
#   'Platforms',
#   ' ',
#   'quick',
#   'cash',
#   'https://t.co/AlwvHy0mkz',
#   'https://t.co/d3xZ63Xj8j',
#   '\n'],
#  ['@Mrkenneyy',
#   'I',
#   'see',
#   'ur',
#   'tweet',
#   'no',
#   'need',
#   'for',
#   'Google',
#   'lol',
#   'it',
#   'be',
#   'a',
#   'very',
#   'large',
#   'dog',
#   '\n'],
#  ['New',
#   'Google',
#   'Chat',
#   'App',
#   'could',
#   'destroy',
#   'Facebook',
#   'Messenger',
#   'https://t.co/71Cu1vKcOI',
#   '#',
#   'google',
#   '\n'],
#  ['RT', '@lexicaaan', ':', 'Me', 'af', '😂😂😂', 'https://t.co/fUw8UrVIV0', '\n'],
#  ['#',
#   'RADIO',
#   '#',
#   '90s',
#   '#',
#   'juice',
#   'Now',
#   'play',
#   '#',
#   'Breathe',
#   '(',
#   'Radio',
#   'Edit',
#   ')',
#   '#',
#   'MIDGE',
#   'URE',
#   '#',
#   'APPS',
#   'Apple',
#   'https://t.co/gsMf7U2vzO',
#   'Google',
#   'https://t.co/idypaT7UqA',
#   '\n'],
#  ['@sebast_lj',
#   '@McFaul',
#   '@Inna4848',
#   "'cause",
#   'google',
#   'translate',
#   'it',
#   'as',
#   '"',
#   'return',
#   'to',
#   'California',
#   '"',
#   '\n'],
#  ['My',
#   'Google',
#   'Play',
#   'account',
#   'make',
#   'me',
#   'realize',
#   'I',
#   'be',
#   'a',
#   'dysfunctional',
#   'teen',
#   'with',
#   'deep',
#   'emotional',
#   'scars',
#   '.',
#   '\n'],
#  ['Latest',
#   'Update',
#   'Brings',
#   'New',
#   'Skills',
#   'To',
#   'The',
#   '#',
#   'AmazonEcho',
#   '\n'],
#  ['https://t.co/O6DxVu9zXy', 'https://t.co/zGNxP3vybq', '\n'],
#  ['RT',
#   '@f396',
#   ':',
#   "'",
#   'Iran',
#   'have',
#   'a',
#   'long',
#   'record',
#   'in',
#   'attack',
#   'foreign',
#   'diplomatic',
#   'missions',
#   ',',
#   "'",
#   'Saudi',
#   '...',
#   '-',
#   'https://t.co/3gaSRB3osT',
#   'via',
#   'https://t.co/UjStGmTT2f',
#   '\n'],
#  ['RT',
#   'shenbrood',
#   'What',
#   'be',
#   'your',
#   'greatest',
#   '#',
#   'digitalmarketing',
#   '#',
#   'contentmarket',
#   'blunder',
#   '?',
#   ' ',
#   'Well',
#   'for',
#   'me',
#   'it',
#   'be',
#   'the',
#   'ever',
#   'change',
#   'Google',
#   'algorith',
#   '.',
#   ' ',
#   'What',
#   'a',
#   '…',
#   '\n'],
#  ['RT',
#   'MasterMindDBS',
#   'shenbrood',
#   ':',
#   'What',
#   'be',
#   'your',
#   'greatest',
#   '#',
#   'digitalmarketing',
#   '#',
#   'contentmarket',
#   'blunder',
#   '?',
#   ' ',
#   'Well',
#   'for',
#   'me',
#   'it',
#   'be',
#   'the',
#   'ever',
#   'change',
#   'Google',
#   'al',
#   '…',
#   '\n'],
#  ['https://t.co/eLiFeXQvA1', 'just', 'like', 'real', 'life', '\n'],
#  ['I',
#   'like',
#   'a',
#   '@YouTube',
#   'video',
#   'https://t.co/52uUx0cXqW',
#   '10',
#   'Things',
#   'You',
#   'should',
#   'Never',
#   'Google',
#   '(',
#   'WARNING',
#   'GROSS',
#   ')',
#   '\n'],
#  ['Here',
#   'be',
#   'what',
#   'happen',
#   'to',
#   '@_snats',
#   'when',
#   'he',
#   'can',
#   'not',
#   'access',
#   'google',
#   'translate',
#   '\n'],
#  ['https://t.co/EtprZXOGzD', '\n'],
#  ['RT',
#   '@Kappa_Kappa',
#   ':',
#   'The',
#   'first',
#   'time',
#   'someone',
#   'comment',
#   '"',
#   'Schwing',
#   '!',
#   '"',
#   'on',
#   'one',
#   'of',
#   'my',
#   'selfies',
#   ',',
#   'I',
#   'have',
#   'to',
#   'google',
#   'what',
#   'it',
#   'be',
#   '.',
#   'It',
#   'be',
#   'basically',
#   'an',
#   'old',
#   'guy',
#   'c',
#   '…',
#   '\n'],
#  ['RT',
#   '@CarlaLioness',
#   ':',
#   '✔TWEETSHEET➡PETITIONS',
#   '-',
#   'PART',
#   '3✔',
#   'SUPPORT',
#   'THE',
#   'FIGHT',
#   'AGAINST',
#   'DOG&amp;CAT',
#   '#',
#   'MEATINDUSTRY',
#   'IN',
#   '#',
#   'SouthKorea',
#   'https://t.co/TKildjZJNr',
#   'http',
#   '…',
#   '\n'],
#  ['RT',
#   'SEOTraverseCity',
#   'shenbrood',
#   ':',
#   'What',
#   'be',
#   'your',
#   'greatest',
#   '#',
#   'digitalmarketing',
#   '#',
#   'contentmarket',
#   'blunder',
#   '?',
#   ' ',
#   'Well',
#   'for',
#   'me',
#   'it',
#   'be',
#   'the',
#   'ever',
#   'change',
#   'Google',
#   '…',
#   '\n'],
#  ['RT', '@NineLivesF', ':', 'A', 'kitten', 'call', 'WANDA', '...', '\n'],
#  ['Many',
#   'of',
#   'you',
#   'have',
#   'ask',
#   'how',
#   'WANDA',
#   'come',
#   'to',
#   'be',
#   'at',
#   'Nine',
#   'Lives',
#   'Foundation',
#   ',',
#   'pair',
#   'up',
#   'with',
#   '…',
#   'https://t.co',
#   '…',
#   '\n'],
#  ['I',
#   'have',
#   'enter',
#   'to',
#   'win',
#   'a',
#   'Google',
#   'Nexus',
#   '6P',
#   'from',
#   '@MakeUseOf',
#   '!',
#   'https://t.co/l1VzzbljaW',
#   '#',
#   'giveaway',
#   '#',
#   'competition',
#   '\n'],
#  ['RT',
#   '@CEEKTechnology',
#   ':',
#   'Google',
#   '#',
#   'Nexus6P',
#   'Review',
#   '-',
#   '#',
#   'Android',
#   'Overdose',
#   'https://t.co/dmIouyVdVk',
#   'via',
#   '@bgdftw',
#   '\n'],
#  ['RT',
#   '@got7style',
#   ':',
#   '[',
#   '#',
#   'B2GETHER',
#   ']',
#   'GOT7',
#   'with',
#   'B',
#   'Connect',
#   'Bracelet',
#   '\n'],
#  ['#',
#   'JB',
#   ' ',
#   '#',
#   'JACKSON',
#   ' ',
#   '#',
#   'TEAMGOT7',
#   '#',
#   'GOT7STYLE',
#   '\n'],
#  ['https://t.co/VCVVUZfGNU', '…', 'https://t.co/BueT9Zr', '…', '\n'],
#  ['iRULU',
#   'Tablet',
#   'PC',
#   'eXpro',
#   'X1s',
#   '7',
#   '"',
#   '8GB/1',
#   'GB',
#   'Google',
#   'Android',
#   '4.4',
#   'Kitkat',
#   'Quad',
#   'Core',
#   'Black',
#   '-',
#   'Bid',
#   'Now',
#   '!',
#   '…',
#   'https://t.co/viBaz8kJeJ',
#   'https://t.co/H4F9cY3Orq',
#   '\n'],
#  ['NEW',
#   'IRULU',
#   '7',
#   '"',
#   'Purple',
#   '16',
#   'GB',
#   'Google',
#   'Android',
#   '4.4',
#   'KitKat',
#   'eXpro',
#   'X1a',
#   'HD',
#   'Tablet',
#   'Quad',
#   'Core',
#   '-',
#   'Bid',
#   'Now',
#   '…',
#   'https://t.co/iVcQ3EAG9L',
#   'https://t.co/3dOYcr12zX',
#   '\n'],
#  ['This',
#   'House',
#   'be',
#   'For',
#   'Sale',
#   ',',
#   'And',
#   'What',
#   'Google',
#   'Maps',
#   'Caught',
#   'Inside',
#   'explain',
#   'The',
#   'C',
#   '...',
#   'https://t.co/nLCtPwNYXv',
#   'https://t.co/MEL4kTftvK',
#   '\n'],
#  ['I',
#   'just',
#   'receive',
#   'a',
#   'reward',
#   ':',
#   'An',
#   'Apple',
#   'a',
#   'Day',
#   'https://t.co/D5BMjL5RIs',
#   '#',
#   'Android',
#   '#',
#   'Androidgames',
#   '#',
#   'Gameinsight',
#   '\n'],
#  ['I',
#   'just',
#   'receive',
#   'a',
#   'reward',
#   ':',
#   'An',
#   'Apple',
#   'a',
#   'Day',
#   'https://t.co/D5BMjL5RIs',
#   '#',
#   'Android',
#   '#',
#   'Gameinsight',
#   '#',
#   'Androidgames',
#   '\n'],
#  ['RT',
#   '@dronelaws',
#   ':',
#   'Status',
#   'report',
#   'on',
#   'the',
#   'NTIA',
#   'multi',
#   '-',
#   'stakeholder',
#   'drone',
#   'privacy',
#   'process',
#   '.',
#   'https://t.co/fN8JLkPty7',
#   '\n'],
#  ['braided',
#   'beard',
#   '-',
#   'Google',
#   'Search',
#   '-',
#   '#',
#   'fashion',
#   '#',
#   'mensfashion',
#   '#',
#   'style',
#   'https://t.co/OFWf8Tqutc',
#   'https://t.co/HIIQ8uUG8J',
#   '\n'],
#  ['King',
#   'of',
#   'dark',
#   'fantasy',
#   '.',
#   'Summon',
#   'today',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/8UfUVFoh4y',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/ZfelsWY2zH',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['Google', 'and', 'Share', ':', 'YOUR', 'RADIATION', 'THIS', 'WEEK', '\n'],
#  ['and',
#   'tell',
#   'your',
#   'friends',
#   'and',
#   'neighbors',
#   ';',
#   'your',
#   'governments',
#   'already',
#   'know',
#   '!',
#   '\n'],
#  ['WE', '...', 'https://t.co/aYtDQbG3O6', '\n'],
#  ['G+',
#   ':',
#   'Somethings',
#   'change',
#   'as',
#   'you',
#   'no',
#   'longer',
#   'want',
#   'to',
#   'live',
#   'within',
#   'the',
#   'same',
#   'dusty',
#   'hallways',
#   '.',
#   ' ',
#   'Thing',
#   'be',
#   'that',
#   'as',
#   'you',
#   'clean',
#   'up',
#   '…',
#   'https://t.co/CD2Hb1VxDE',
#   '\n'],
#  ['Texas',
#   'college',
#   'student',
#   'kill',
#   'in',
#   'New',
#   'Year',
#   "'s",
#   'Eve',
#   'shooting',
#   '-',
#   'CNN',
#   'International',
#   '\n'],
#  ['https://t.co/NKVXMvg5Vs', '\n'],
#  ['https://t.co/57W1xcPUNv',
#   'check',
#   'out',
#   'this',
#   'page',
#   'for',
#   'the',
#   'hottest',
#   'music',
#   'trends',
#   'and',
#   'more',
#   ',',
#   'search',
#   'your',
#   'favorite',
#   'music',
#   '2',
#   'https://t.co/g7gsLtZe0S',
#   '\n'],
#  ['https://t.co/EPop7HMqk3',
#   'hey',
#   'check',
#   'out',
#   'these',
#   '2016',
#   'amazon',
#   'tips',
#   'https://t.co/7OvQwnG3Qs',
#   '\n'],
#  ['New',
#   'Event',
#   'Now',
#   'On',
#   '.',
#   'get',
#   'New',
#   'Rank',
#   'S',
#   'Monsters',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/ioRDcpAe0t',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/3q1ftPNi3p',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['RT', '@GOPof_idiots', ':', '@jeanettej', '\n'],
#  ['None', '...', 'but', '#', 'Bernie', 'do', '!', '\n'],
#  ['https://t.co/t5sRAPBFvi', 'https://t.co/wZS2PR80QP', '\n'],
#  ['seem',
#   'like',
#   'my',
#   'boss',
#   'be',
#   'interested',
#   'enough',
#   'in',
#   'Chen',
#   ',',
#   'he',
#   'just',
#   'google',
#   'Chen',
#   "'s",
#   'pic',
#   'and',
#   'show',
#   'it',
#   'to',
#   'me',
#   '"',
#   'be',
#   'this',
#   'Chen',
#   '?',
#   'He',
#   'look',
#   'like',
#   'pondan',
#   '.',
#   '"',
#   '\n'],
#  ['RT',
#   '@PYPRecords',
#   ':',
#   'look',
#   'us',
#   'up',
#   'on',
#   'iTunes',
#   'just',
#   'google',
#   'the',
#   'name',
#   'Popcorn',
#   'PYP',
#   'or',
#   'come',
#   'to',
#   'NYC',
#   'and',
#   'ask',
#   'for',
#   'me',
#   'https://t.co/4Xydj87TZk',
#   '\n'],
#  ['do',
#   "n't",
#   'google',
#   'Any',
#   'Of',
#   'These',
#   'Terms',
#   'No',
#   'Matter',
#   'How',
#   'Bad',
#   'You',
#   'want',
#   'To',
#   '!',
#   '...',
#   'https://t.co/F4o4XGbSpD',
#   '\n'],
#  ['@hadley_delducaa',
#   'yeah',
#   'but',
#   'its',
#   'worth',
#   'a',
#   'google',
#   'https://t.co/ZdHrvt3VuE',
#   '\n'],
#  ['RT',
#   '@darkenedsight',
#   ':',
#   'Taylor',
#   "'s",
#   'gon',
#   'na',
#   'punch',
#   'me',
#   ',',
#   'now',
#   'I',
#   'have',
#   'to',
#   'google',
#   'search',
#   'how',
#   'to',
#   'act',
#   'as',
#   'if',
#   'it',
#   'hurt',
#   '.',
#   'Brb',
#   '😇😆',
#   '\n'],
#  ['Pluralsight',
#   '–',
#   'get',
#   'start',
#   'with',
#   'Google',
#   'Play',
#   'In',
#   '-',
#   'app',
#   'Billing',
#   'https://t.co/PLmEvqWGdh',
#   '\n'],
#  ['@seedchan',
#   'ill',
#   'send',
#   'you',
#   'your',
#   'card',
#   'from',
#   'tw',
#   '!',
#   '!',
#   'https://t.co/AFhRYYUytH',
#   '\n'],
#  ['Not', 'even', 'google', 'can', 'help', 'https://t.co/2sImxSyIP3', '\n'],
#  ['not',
#   'gon',
#   'na',
#   'lie',
#   ',',
#   'I',
#   'just',
#   'type',
#   '"',
#   'what',
#   'to',
#   'wear',
#   'when',
#   'it',
#   'be',
#   '-15',
#   'degrees',
#   'on',
#   'the',
#   'outside',
#   '"',
#   'in',
#   'google',
#   '\n'],
#  ['Samsung',
#   ':',
#   'Dear',
#   'samsung',
#   'i',
#   'be',
#   'very',
#   'annoyed',
#   'i',
#   'can',
#   'not',
#   'revert',
#   'to',
#   'kitkat',
#   'from',
#   'lollipop',
#   'i',
#   'have',
#   'contact',
#   'google',
#   'my',
#   'provider',
#   'opt',
#   '-',
#   'https://t.co/MZn2AajhHf',
#   '\n'],
#  ['check',
#   'out',
#   'Gosford',
#   'Park',
#   'on',
#   'https://t.co/dmGGQ8wiR6',
#   '#',
#   'hoopladigital',
#   '\n'],
#  ['British', 'Mystery', 'Robert', 'Altman', 'GREAT', '!', 'Aleta', '\n'],
#  ['\n'],
#  ['https://t.co/ERHPlxkpTr', '\n'],
#  ['ECO',
#   '100',
#   'WK',
#   '10',
#   'QUIZ',
#   'CHAPTERS',
#   '16',
#   'AND',
#   '17',
#   '-',
#   'https://t.co/BURTA5bO3w',
#   '\n'],
#  ['@2pmphilippines',
#   'pls',
#   'help',
#   'rt',
#   '?',
#   '^_^',
#   'https://t.co/x4KmKmIL9R',
#   '\n'],
#  ['Google',
#   "'s",
#   'CEO',
#   'think',
#   'Vietnam',
#   '-',
#   'Home',
#   'to',
#   'the',
#   'Next',
#   'Big',
#   'Startup',
#   'Scene',
#   '\n'],
#  ['https://t.co/Z4pjChf85K', '\n'],
#  ['https://t.co/mZMkRLuuM5', 'https://t.co/gyq6YUXe0S', '\n'],
#  ['get', 'your', 'songs', 'on', 'iTunes', '/', 'Google', 'play', 'etc', '\n'],
#  ['RT',
#   '@beautiigirls',
#   ':',
#   'This',
#   'House',
#   'be',
#   'For',
#   'Sale',
#   ',',
#   'Cheap',
#   '.',
#   'When',
#   'You',
#   'see',
#   'What',
#   'Google',
#   'Maps',
#   'Caught',
#   ',',
#   'You',
#   'will',
#   'see',
#   'Why',
#   '!',
#   'https://t.co/gAy9fc3q7s',
#   'https://t.co',
#   '…',
#   '\n'],
#  ['@occamsboner',
#   '@jonathanchait',
#   'Instead',
#   'of',
#   'ask',
#   'everyone',
#   'on',
#   'Twitter',
#   ',',
#   ' ',
#   'why',
#   'do',
#   "n't",
#   'you',
#   'Google',
#   'it',
#   '?',
#   '#',
#   'weirdo',
#   '\n'],
#  ['What',
#   'Google',
#   'say',
#   'About',
#   'SEO',
#   'in',
#   '2016',
#   '-',
#   'WebProNews',
#   'https://t.co/t1tdp1IPgl',
#   '\n'],
#  ['Gandalf',
#   '=',
#   'Google',
#   'maps',
#   '.',
#   'Gollum',
#   '=',
#   'Apple',
#   'maps',
#   '.',
#   '\n'],
#  ['You',
#   'be',
#   'not',
#   'go',
#   'to',
#   'get',
#   'away',
#   'with',
#   'this',
#   'Mr.',
#   'Google',
#   'Search',
#   '\n'],
#  ['RT',
#   '@stephen_mcd',
#   ':',
#   'Django',
#   '1.9',
#   'support',
#   'just',
#   'land',
#   'in',
#   'Mezzanine',
#   ',',
#   'please',
#   'help',
#   'test',
#   'it',
#   ':',
#   'https://t.co/WAIshyBSdp',
#   '#',
#   'django',
#   '\n'],
#  ['try',
#   'TunnelBear',
#   'for',
#   '\xa0',
#   'Chrome',
#   '\xa0',
#   'to',
#   'browse',
#   'like',
#   'you',
#   'be',
#   'in',
#   'another',
#   'country',
#   ':',
#   '\xa0',
#   'https://t.co/1x01dEAPHt',
#   '\xa0',
#   '@theTunnelBear',
#   '\xa0',
#   'https://t.co/EwVXPQZCCP',
#   '\n'],
#  ['2060',
#   ':',
#   'Little',
#   'Red',
#   'Schoolhouse',
#   'slates',
#   'open',
#   'house',
#   ',',
#   'Jan.',
#   '9',
#   '-',
#   'Wicked',
#   'Local',
#   'Bellingham',
#   'https://t.co/9XGhBcO148',
#   '\n'],
#  ['RT',
#   '@WearableGuru',
#   ':',
#   'Google',
#   'Glass',
#   'live',
#   '!',
#   'see',
#   'The',
#   'Leaked',
#   'Photos',
#   'of',
#   'The',
#   'Next',
#   'Version',
#   'https://t.co/R4vNOJa1kF',
#   '#',
#   'WearableTech',
#   '#',
#   'Wearables',
#   'https://t',
#   '.',
#   '…',
#   '\n'],
#  ['"', 'The', 'Papi', '"', 'ep', '$', '3.99', 'on', 'Google', 'Play', '\n'],
#  ['https://t.co/FifS8XFp4A', 'https://t.co/ht0H4VZ2jn', '\n'],
#  ['Whn',
#   'ur',
#   'fnish',
#   'wth',
#   'an',
#   'essay',
#   ',',
#   'copy',
#   'and',
#   'paste',
#   'it',
#   'into',
#   'Google',
#   'Translate',
#   'and',
#   'lsten',
#   'to',
#   'it',
#   'Its',
#   'the',
#   'easiest',
#   'way',
#   'to',
#   'find',
#   'mistakes',
#   '#',
#   'ShowtimeTrabahuLa',
#   '\n'],
#  ['Eminem', '-', 'Not', 'Afraid', 'https://t.co/AexXn2vafi', '\n'],
#  ['https://t.co/NlBOFNoUl3',
#   '-',
#   'Google',
#   'Defeats',
#   'Copyright',
#   'Lawsuit',
#   'Over',
#   'Waze',
#   'Data',
#   '(',
#   'Forbes',
#   'Cross',
#   '-',
#   'Post',
#   ')',
#   '\n'],
#  ['i',
#   'be',
#   'try',
#   'to',
#   'google',
#   '"',
#   'oh',
#   'yeah',
#   'eat',
#   'that',
#   'bible',
#   '"',
#   'for',
#   'whatever',
#   'reason',
#   'without',
#   'die',
#   'https://t.co/0pzvtMWF5M',
#   '\n'],
#  ['Techniques',
#   'of',
#   'teach',
#   'Arabic',
#   ' ',
#   'as',
#   'a',
#   'Foreign',
#   'Language',
#   'through',
#   'Constructivist',
#   'Paradigm',
#   ':',
#   'Malaysian',
#   'Perspective',
#   'https://t.co/Y95mgN9JOT',
#   '\n'],
#  ['RT',
#   '@LovinGianni',
#   ':',
#   'come',
#   'at',
#   'me',
#   'with',
#   'something',
#   'that',
#   'be',
#   ' ',
#   'grammatically',
#   'incorrect',
#   'I',
#   'be',
#   'fire',
#   'yo',
#   'ass',
#   'up',
#   'with',
#   'words',
#   'you',
#   'go',
#   'have',
#   'to',
#   'Google',
#   '.',
#   '\n'],
#  ['RT', '@GOPof_idiots', ':', '@Libertea2012', '\n'],
#  ['let',
#   'help',
#   'Bernie',
#   'get',
#   'his',
#   'message',
#   'out',
#   'since',
#   'the',
#   'media',
#   'be',
#   'not',
#   'help',
#   'him',
#   'like',
#   'they',
#   'r',
#   'Hillary',
#   '&',
#   'amp',
#   ';',
#   'trump',
#   'https',
#   ':',
#   '…',
#   '\n'],
#  ['I',
#   'be',
#   'now',
#   'an',
#   'E',
#   '-',
#   'List',
#   'celebrity',
#   'in',
#   'Kim',
#   'Kardashian',
#   ':',
#   'Hollywood',
#   '.',
#   'You',
#   'can',
#   'be',
#   'famous',
#   'too',
#   'by',
#   'play',
#   'on',
#   'Android',
#   '!',
#   'https://t.co/N7IobTzhjh',
#   '\n'],
#  ['New',
#   'Event',
#   'Now',
#   'On',
#   '.',
#   'get',
#   'New',
#   'Rank',
#   'S',
#   'Monsters',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/MfM7E5Kn5e',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/hTvSZdvuuz',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['Native',
#   'American',
#   'Flute',
#   'Music',
#   ':',
#   'Meditation',
#   'Music',
#   'for',
#   'Shamanic',
#   'Astral',
#   'Projection',
#   ',',
#   'Healing',
#   'Music',
#   'https://t.co/4kq77Fihw7',
#   '\n'],
#  ['RT',
#   '@ezralevant',
#   ':',
#   'Here',
#   'be',
#   'why',
#   'I',
#   'be',
#   'worried',
#   'about',
#   'censorship',
#   'from',
#   '@google',
#   ',',
#   '@twitter',
#   '&',
#   'amp',
#   ';',
#   '@facebook',
#   'in',
#   '2016',
#   '.',
#   'Because',
#   'they',
#   'say',
#   'they',
#   'will',
#   'do',
#   'it',
#   ':',
#   'https:/',
#   '…',
#   '\n'],
#  ['Course',
#   'Materials',
#   'for',
#   'Statistics',
#   '(',
#   'The',
#   'Easier',
#   'Way',
#   ')',
#   'With',
#   'R',
#   'https://t.co/b4UDeHX8ZE',
#   '#',
#   'rstats',
#   '\n'],
#  ['RT',
#   '@TheMoneyGenie',
#   ':',
#   '3',
#   'Big',
#   'Lessons',
#   'from',
#   '3',
#   'Successful',
#   'Entrepreneurs',
#   ' ',
#   'work',
#   'from',
#   'home',
#   'https://t.co/efgCnlgB9X',
#   'https://t.co/ZPkeT3x8e4',
#   '\n'],
#  ['Google', '"', 'puckle', 'gun', '"', '.', 'https://t.co/jQW6RkFDT7', '\n'],
#  ['Hip',
#   'Hop',
#   'Alumni',
#   '#',
#   'HHA',
#   '@google',
#   'Blogger',
#   'https://t.co/eZEMPn9xBT',
#   '&',
#   'amp',
#   ';',
#   'https://t.co/Zq15au76CJ',
#   '#',
#   'HHA',
#   '@YouTube',
#   'Channel',
#   'https://t.co/qBZDnI5TcB',
#   '2016',
#   '\n'],
#  ['@rustybrick',
#   'sir',
#   'please',
#   'tell',
#   'me',
#   'latest',
#   '@google',
#   'Algorithm',
#   'in',
#   '2016',
#   '\n'],
#  ['@Kappa_Kappa',
#   'you',
#   'have',
#   'to',
#   'google',
#   'it',
#   'for',
#   'real',
#   '?',
#   '\n'],
#  ['2057',
#   ':',
#   'Paul',
#   'Jacoulet',
#   "'s",
#   'widowed',
#   'mother',
#   'remarry',
#   'and',
#   'settle',
#   'in',
#   'Korea',
#   '.',
#   'His',
#   '-',
#   'Maine',
#   'Antique',
#   'Digest',
#   'https://t.co/3Ed80jHX7t',
#   '\n'],
#  ['RT',
#   '@abogomolov',
#   ':',
#   'New',
#   'in',
#   'Symfony',
#   '2.8',
#   ':',
#   'DX',
#   'Improvements',
#   '\n'],
#  ['\n'],
#  ['https://t.co/jD8V92Swz2', '#', 'symfony', '\n'],
#  ['@Georgina944',
#   'go',
#   'to',
#   'this',
#   'website',
#   '.',
#   'https://t.co/4O42egV2MV',
#   'copy',
#   'and',
#   'paste',
#   'it',
#   'in',
#   'twitter',
#   '.',
#   'Tweet',
#   'more',
#   'for',
#   '#',
#   'TeamSeventeen',
#   '\n'],
#  ['Phase',
#   'One',
#   'XF',
#   '100MP',
#   'use',
#   'similar',
#   'A7rII',
#   'sensor',
#   'tech',
#   '.',
#   'First',
#   'short',
#   'image',
#   'test',
#   'impressions',
#   '.',
#   '|',
#   '…',
#   'https://t.co/sreo7UQy1m',
#   'https://t.co/Qe2kKF44KC',
#   '\n'],
#  ['Morgan', 'Monday', '\n'],
#  ['\n'],
#  ['Congress', ':', '\n'],
#  ['https://t.co/fMqqb0UjNZ', '\n'],
#  ['\n'],
#  ['English', ':', '\n'],
#  ['https://t.co/ugQ8CeyEFT', '\n'],
#  ['\n'],
#  ['German', ':', '\n'],
#  ['https://t.co/5ottfHrhgW', 'https://t.co/6EM90xm591', '\n'],
#  ['Eminem',
#   '-',
#   'The',
#   'Real',
#   'Slim',
#   'Shady',
#   '(',
#   'Edited',
#   ')',
#   'https://t.co/RJHB3ZK07s',
#   '\n'],
#  ['I',
#   'have',
#   'enter',
#   'to',
#   'win',
#   'a',
#   'Google',
#   'Nexus',
#   '6P',
#   'from',
#   '@MakeUseOf',
#   '!',
#   'https://t.co/y8fiCNFWHo',
#   '#',
#   'giveaway',
#   '#',
#   'competition',
#   '\n'],
#  ['RT',
#   '@RealGoaIs',
#   ':',
#   'when',
#   'you',
#   'google',
#   'one',
#   'question',
#   'and',
#   'find',
#   'a',
#   'quizlet',
#   'for',
#   'the',
#   'whole',
#   'test',
#   'https://t.co/wKVjfkbIug',
#   '\n'],
#  ['RT',
#   '@teropa',
#   ':',
#   'Google',
#   'analytics',
#   'tell',
#   'me',
#   'the',
#   'Full',
#   '-',
#   'Stack',
#   'Redux',
#   'Tutorial',
#   'have',
#   'pass',
#   '110k',
#   'visitors',
#   '.',
#   'That',
#   '’s',
#   'crazy',
#   '.',
#   '\n'],
#  ['RT', '@mikealbers23', ':', 'Great', 'new', 'workout', 'app', '!', '\n'],
#  ['https://t.co/m7H5yTCVew', '\n'],
#  ['\n'],
#  ['#',
#   'workout',
#   '#',
#   'fitness',
#   '#',
#   'gym',
#   '#',
#   'exercise',
#   '#',
#   'health',
#   '\n'],
#  ['#', 'DowntonAbbey', '#', 'quickworkout', 'http', '…', '\n'],
#  ['@lawwrah',
#   '@kLa_AnNe33',
#   '@itsOTHquotes',
#   'do',
#   "n't",
#   'google',
#   'any',
#   'of',
#   'it',
#   '...',
#   'I',
#   'always',
#   'make',
#   'that',
#   'mistake',
#   '...',
#   'Still',
#   'SO',
#   'GOOD',
#   'though',
#   '!',
#   '❤️',
#   '\n'],
#  ['@Aizanzenzon',
#   'go',
#   'google',
#   'about',
#   'it',
#   'and',
#   'whatsapp',
#   'me',
#   'we',
#   'can',
#   'always',
#   'plan',
#   '😉',
#   '\n'],
#  ['iPhone',
#   'and',
#   'iPad',
#   'prices',
#   'go',
#   'up',
#   'in',
#   'Germany',
#   'due',
#   'to',
#   'country',
#   "'s",
#   'private',
#   'copying',
#   'fees',
#   'https://t.co/lf6zyvpAkN',
#   '\n'],
#  ['Wedding',
#   'gown',
#   'survive',
#   'tornado',
#   ':',
#   'Illinois',
#   'farmer',
#   'help',
#   'reunite',
#   'bride',
#   'with',
#   '...',
#   '-',
#   'KTRK',
#   '-',
#   'TV',
#   'https://t.co/1VGqKNs8RW',
#   '\n'],
#  ['@GauravPandhi',
#   '@ZubinaAhmad',
#   '@SamarG_Uvaach',
#   '@reviewero',
#   'If',
#   'u',
#   'want',
#   'to',
#   'play',
#   'dirty',
#   'politics',
#   'then',
#   'their',
#   'r',
#   'enough',
#   'to',
#   'be',
#   'find',
#   'on',
#   'Google',
#   'against',
#   'BJP',
#   '\n'],
#  ['fuse',
#   'Location',
#   'Provider',
#   'in',
#   'Google',
#   'Play',
#   'services8.4',
#   'provide',
#   'location',
#   'to',
#   'an',
#   'app.https://t.co/mrVKMESQgD',
#   '\n'],
#  ['#', 'developers', 'https://t.co/WbQFXE1P3Q', '\n'],
#  ['turn',
#   'Your',
#   'Phone',
#   'Into',
#   'A',
#   'Lightsaber',
#   'With',
#   'This',
#   'Mind',
#   '-',
#   'blow',
#   'Google',
#   'Chrome',
#   'Experiment',
#   ':',
#   'https://t.co/Y1Y6RmxfFd',
#   '#',
#   'StarWars',
#   '\n'],
#  ['@hollyheatbeat',
#   'go',
#   'to',
#   'this',
#   'website',
#   '.',
#   'https://t.co/4O42egV2MV',
#   'copy',
#   'and',
#   'paste',
#   'it',
#   'in',
#   'twitter',
#   '.',
#   'Tweet',
#   'more',
#   'for',
#   '#',
#   'TeamSeventeen',
#   '\n'],
#  ['TwitPane', '  ', 'https://t.co/OnQ3Cklkz0', '\n'],
#  ['From',
#   'Digital',
#   'Disappointment',
#   'ToThe',
#   'End',
#   'Of',
#   'The',
#   'App',
#   'Era',
#   ',',
#   'Here',
#   'be',
#   'Eight',
#   'Trends',
#   'For',
#   'https://t.co/KRsMRJKApr',
#   '\n'],
#  ['RT', '@Senyora', ':', 'dam', 'handa', 'ah', '.', 'Google', '?', '\n'],
#  ['would',
#   'your',
#   'company',
#   'benefit',
#   'from',
#   'a',
#   'tailored',
#   '#',
#   'Google',
#   '&',
#   'amp',
#   ';',
#   '#',
#   'SocialMedia',
#   'seminar',
#   '?',
#   '0161',
#   '432',
#   '7268',
#   'https://t.co/rkfnLTbsMD',
#   'https://t.co/DJZalMKRIN',
#   '\n'],
#  ['What',
#   'be',
#   'the',
#   'Best',
#   'Google',
#   'AdSense',
#   '\xa0',
#   'Forums',
#   '?',
#   'https://t.co/TMf2G9CyID',
#   '\n'],
#  ['RT',
#   '@TheMoneyGenie',
#   ':',
#   'Why',
#   'Themeforest',
#   'be',
#   'Awesome',
#   'for',
#   'buy',
#   'Custom',
#   'Templates',
#   ' ',
#   'work',
#   'from',
#   'home',
#   'https://t.co/Ok76Fjda8g',
#   'https://t.co/K2vXu9uLG0',
#   '\n'],
#  ['RT',
#   '@artfulkiss',
#   ':',
#   'I',
#   'GOOGLE',
#   'EARTHED',
#   'MY',
#   'HOUSE',
#   'AND',
#   'I',
#   'see',
#   'SOMETHING',
#   'IN',
#   'MY',
#   'WINDOW',
#   'AND',
#   'ITS',
#   'LOUIS',
#   "'",
#   'CARDBOARD',
#   'CUT',
#   'OUT',
#   'http://t.co/dw0Ln5rI6B',
#   '\n'],
#  ['@CKirubi',
#   'Hello',
#   'sir',
#   'watch',
#   'my',
#   'new',
#   'video',
#   'https://t.co/NTs3QM5YU5',
#   '\n'],
#  ['RT', '@RealShigeruM', ':', 'DOn’t', 'google', 'sexy', 'yoshi', '\n'],
#  ['RT',
#   'https://t.co/NrWzkMqWUs',
#   'Fashion',
#   'Apparel',
#   'and',
#   'Retail',
#   'Stocks',
#   'End',
#   '2015',
#   'With',
#   'Whimper',
#   '-',
#   'WWD',
#   '\n'],
#  ['\n'],
#  ['Fashion', 'Apparel', 'and', 'Ret', '…', 'https://t.co/fYqLDa0aEM', '\n'],
#  ['King',
#   'of',
#   'dark',
#   'fantasy',
#   '.',
#   'Summon',
#   'today',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/YeXVlJbelW',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/ShfEVT575M',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['would',
#   'your',
#   'company',
#   'benefit',
#   'from',
#   'a',
#   'tailored',
#   '#',
#   'Google',
#   '&',
#   'amp',
#   ';',
#   '#',
#   'SocialMedia',
#   'seminar',
#   '?',
#   '0161',
#   '432',
#   '7268',
#   'https://t.co/rkfnLTbsMD',
#   '...',
#   'https://t.co/wCW9B1YATQ',
#   '\n'],
#  ['RT',
#   '@LovinGianni',
#   ':',
#   'come',
#   'at',
#   'me',
#   'with',
#   'something',
#   'that',
#   'be',
#   ' ',
#   'grammatically',
#   'incorrect',
#   'I',
#   'be',
#   'fire',
#   'yo',
#   'ass',
#   'up',
#   'with',
#   'words',
#   'you',
#   'go',
#   'have',
#   'to',
#   'Google',
#   '.',
#   '\n'],
#  ['RT',
#   'famina',
#   '#',
#   'Europe',
#   'could',
#   'produce',
#   'a',
#   'Facebook',
#   '–',
#   'and',
#   'the',
#   'Google',
#   'of',
#   '#',
#   'healthcare',
#   '-',
#   'https://t.co/WJpmOQD9bE',
#   '#',
#   'impact',
#   '#',
#   'socbiz',
#   '#',
#   'biz',
#   '\n'],
#  ['@Lee_YooYoung',
#   '_',
#   'translate',
#   'to',
#   'google',
#   'then',
#   ':',
#   '"',
#   'c',
#   '\n'],
#  ['I',
#   'have',
#   'enter',
#   'to',
#   'win',
#   'a',
#   'Google',
#   'Nexus',
#   '6P',
#   'from',
#   ' ',
#   '!',
#   '   ',
#   'https://t.co/THsIoBZwZV',
#   '\n'],
#  ['What',
#   'be',
#   'the',
#   'Best',
#   'Google',
#   'AdSense',
#   '\xa0',
#   'Forums',
#   '?',
#   'https://t.co/OzYGbXSzzK',
#   '\n'],
#  ['@jasondemanzo',
#   'With',
#   'as',
#   'much',
#   'as',
#   'they',
#   'pay',
#   'in',
#   'Luxury',
#   'tax',
#   '&',
#   'amp',
#   ';',
#   'rev',
#   'from',
#   'the',
#   'new',
#   'cable',
#   'deal',
#   'Kobe',
#   'deal',
#   'be',
#   'nt',
# ...
#   '....',
#   '@carlythekatycat',
#   'be',
#   'all',
#   'that',
#   'come',
#   'up',
#   '\n'],
#  ['@pdhana',
#   '@BKDoss',
#   '@psrajarajan',
#   '@plk_raja',
#   'google',
#   'itself',
#   'be',
#   'make',
#   'comedy',
#   '.',
#   'EV',
#   'Ramasamy',
#   'naaickar',
#   '😛😜😀',
#   'https://t.co/6MozJHn4Ef',
#   '\n'],
#  ['#',
#   'Google',
#   'Helps',
#   'Analyze',
#   'If',
#   'Rooftop',
#   'Solar',
#   'Panels',
#   'be',
#   'Good',
#   'Deal',
#   '-',
#   'https://t.co/Rhrbhfp2jm',
#   'https://t.co/tAFANCZrmH',
#   '\n'],
#  ['#',
#   'Google',
#   'Helps',
#   'Analyze',
#   'If',
#   'Rooftop',
#   'Solar',
#   'Panels',
#   'be',
#   'Good',
#   'Deal',
#   '-',
#   'https://t.co/CsKw2KMhUf',
#   'https://t.co/2tFPr3lpXZ',
#   '\n'],
#  ['#',
#   'Google',
#   'Helps',
#   'Analyze',
#   'If',
#   'Rooftop',
#   'Solar',
#   'Panels',
#   'be',
#   'Good',
#   'Deal',
#   '-',
#   'https://t.co/fFkoD7bgTI',
#   'https://t.co/zVuDDXSm8U',
#   '\n'],
#  ['@wedodumbthings',
#   '@TheNamesYousef',
#   '@ACaIabrese',
#   'I',
#   'try',
#   'just',
#   'google',
#   'the',
#   'ones',
#   'that',
#   'be',
#   "n't",
#   'fillers',
#   '..',
#   'it',
#   'just',
#   'be',
#   "n't",
#   'for',
#   'me',
#   'I',
#   'get',
#   'to',
#   'ep',
#   '200',
#   'lol',
#   '\n'],
#  ['#',
#   'Google',
#   'Helps',
#   'Analyze',
#   'If',
#   'Rooftop',
#   'Solar',
#   'Panels',
#   'be',
#   'Good',
#   'Deal',
#   '-',
#   'https://t.co/1L6AjMOFC2',
#   'https://t.co/1IfzzKcajy',
#   '\n'],
#  ['#',
#   'Google',
#   'Helps',
#   'Analyze',
#   'If',
#   'Rooftop',
#   'Solar',
#   'Panels',
#   'be',
#   'Good',
#   'Deal',
#   '-',
#   'https://t.co/sTpRNxFvcA',
#   'https://t.co/I6ysfMZ3GD',
#   '\n'],
#  ['#',
#   'Google',
#   'Helps',
#   'Analyze',
#   'If',
#   'Rooftop',
#   'Solar',
#   'Panels',
#   'be',
#   'Good',
#   'Deal',
#   '-',
#   'https://t.co/CUvfqQ1pf9',
#   'https://t.co/da35f0YR02',
#   '\n'],
#  ['RT',
#   '@paperphotoyo',
#   ':',
#   'Just',
#   'have',
#   'to',
#   'Google',
#   'synonyms',
#   'for',
#   'the',
#   'word',
#   'creative',
#   '.',
#   '\n'],
#  ['\n'],
#  ['The', 'irony', 'be', 'not', 'lose', 'on', 'me', '.', '\n'],
#  ['RT',
#   '@Arzaylea',
#   ':',
#   '@sweetIieslrh',
#   'Google',
#   '"',
#   'instagram',
#   'bio',
#   'spaces',
#   '"',
#   'and',
#   'it',
#   'will',
#   'let',
#   'you',
#   'copy',
#   'and',
#   'paste',
#   'it',
#   ':)',
#   '\n'],
#  ['Brackets',
#   'update',
#   '!',
#   'change',
#   'sizing',
#   'to',
#   'make',
#   'reading',
#   'easier',
#   ':',
#   'https://t.co/1W3yfwjOgI',
#   '\n'],
#  ['@MariahJordan9',
#   'at',
#   'least',
#   'Google',
#   'be',
#   'try',
#   'to',
#   'say',
#   'a',
#   'life',
#   '\n'],
#  ['What',
#   'self',
#   'fix',
#   'negativity.1',
#   'occur',
#   'google',
#   'present',
#   '-',
#   'time',
#   '40',
#   'days',
#   '-',
#   'my',
#   'recondite',
#   'automation',
#   'lickspit',
#   ':',
#   'OpMg',
#   '\n'],
#  ['Google', 'Cultural', 'Institute', '\n'],
#  ['create',
#   'your',
#   'own',
#   'galleries',
#   'and',
#   'share',
#   'favourite',
#   'find',
#   'with',
#   'friends',
#   '.',
#   '\n'],
#  ['https://t.co/nIx9z94TPc', '\n'],
#  ['I',
#   'be',
#   'now',
#   'a',
#   'D',
#   '-',
#   'List',
#   'celebrity',
#   'in',
#   'Kim',
#   'Kardashian',
#   ':',
#   'Hollywood',
#   '.',
#   'You',
#   'can',
#   'be',
#   'famous',
#   'too',
#   'by',
#   'play',
#   'on',
#   'Android',
#   '!',
#   'https://t.co/7p80x599JO',
#   '\n'],
#  ['love',
#   'this',
#   '!',
#   'check',
#   'out',
#   'All',
#   'for',
#   'One',
#   'by',
#   'Five',
#   'for',
#   'fight',
#   '-',
#   'https://t.co/r34fG3fLCB',
#   '\n'],
#  ['King',
#   'of',
#   'dark',
#   'fantasy',
#   '.',
#   'Summon',
#   'today',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/uCuUIGQxB1',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/xl4W6voTzQ',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['@Nadimah1505',
#   'here',
#   'you',
#   'go',
#   '!',
#   '!',
#   '!',
#   'https://t.co/J7Qly9Pkb1',
#   '\n'],
#  ['RT',
#   '@GoogleExpertUK',
#   ':',
#   'would',
#   'your',
#   'company',
#   'benefit',
#   'from',
#   'a',
#   'tailored',
#   '#',
#   'Google',
#   '&',
#   'amp',
#   ';',
#   '#',
#   'SocialMedia',
#   'seminar',
#   '?',
#   '0161',
#   '432',
#   '7268',
#   'https://t.co/rkfnLTbsMD',
#   'https',
#   ':',
#   '…',
#   '\n'],
#  ['If',
#   'interested',
#   'in',
#   'help',
#   'test',
#   'MazeVR',
#   'for',
#   'Google',
#   'Cardboard',
#   'on',
#   'iPhone',
#   '5',
#   'or',
#   '6',
#   ',',
#   'DM',
#   'your',
#   'email',
#   'address',
#   '.',
#   'TestFlight',
#   'require',
#   'it',
#   '.',
#   'Thanks',
#   '.',
#   '\n'],
#  ['broker',
#   'the',
#   'premium',
#   'domain',
#   ':',
#   'https://t.co/lACAov189I',
#   'interested',
#   '?',
#   '@AOL',
#   '@comcast',
#   '@google',
#   '@yahoo',
#   '@b',
#   '@MSN',
#   '@Microsoft',
#   'ristosdomains@gmail.com',
#   '\n'],
#  ['RT',
#   '@Im__Joshi',
#   ':',
#   '@pdhana',
#   '@BKDoss',
#   '@psrajarajan',
#   '@plk_raja',
#   'google',
#   'itself',
#   'be',
#   'make',
#   'comedy',
#   '.',
#   'EV',
#   'Ramasamy',
#   'naaickar',
#   '😛😜😀',
#   'https://t.co/6MozJHn4Ef',
#   '\n'],
#  ['I',
#   'like',
#   'a',
#   '@YouTube',
#   'video',
#   'https://t.co/j20RVpLTAi',
#   '10',
#   'Things',
#   'You',
#   'should',
#   'Never',
#   'Google',
#   '(',
#   'WARNING',
#   'GROSS',
#   ')',
#   '\n'],
#  ['RT',
#   '@EastRidgeIBL',
#   ':',
#   'Week',
#   '2',
#   'Power',
#   'Rankings😈',
#   ':',
#   'https://t.co/1xfRayMvpX',
#   '\n'],
#  ['Sometimes',
#   'I',
#   'google',
#   'cute',
#   'ways',
#   'to',
#   'ask',
#   'someone',
#   'out',
#   'cause',
#   'my',
#   'ideas',
#   'suck',
#   'asf',
#   '\n'],
#  ['SB',
#   'Nation',
#   ':',
#   'Colts',
#   'vs.',
#   'Titans',
#   'final',
#   'score',
#   ':',
#   'Colts',
#   'beat',
#   'Titans',
#   '30',
#   '-',
#   '24',
#   'in',
#   'what',
#   'be',
#   'likely',
#   'Chuck',
#   'Pagano',
#   "'s",
#   'final',
#   'game',
#   '.',
#   'https://t.co/dFFsd8h1AU',
#   '\n'],
#  ['King',
#   'of',
#   'dark',
#   'fantasy',
#   '.',
#   'Summon',
#   'today',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/8DrU0of1TZ',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/L1BYJ42l47',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['RT',
#   '@LoveLife201114',
#   ':',
#   '#',
#   'MakingAMurderer',
#   '@HelpStevenAvery',
#   '\n'],
#  ['\n'],
#  ['One',
#   'can',
#   'leave',
#   'the',
#   'sherifs',
#   'office',
#   'comments',
#   'via',
#   'Google',
#   'maps',
#   '.',
#   'https://t.co/QDonXt485g',
#   '\n'],
#  ['I',
#   'be',
#   'not',
#   'sure',
#   'what',
#   'you',
#   'mean',
#   '.',
#   'What',
#   'sort',
#   'of',
#   'questions',
#   '?',
#   'I',
#   'like',
#   'Stikman',
#   '.',
#   'Google',
#   'him',
#   '.',
#   'If',
#   'you',
#   'have',
#   'questions',
#   'know',
#   'a',
#   'ton',
#   '.',
#   '\n'],
#  ['#', 'Google', 'answer', 'your', 'questions', '.', '\n'],
#  ['#', 'LarryPage', 'answer', 'the', 'fundamental', 'question', '.', '\n'],
#  ['#', 'MondayMotivation', '#', 'Quote', 'https://t.co/oHHehg9e4s', '\n'],
#  ['Agoa',
#   'trade',
#   'stand',
#   '-',
#   'off',
#   ':',
#   'Ties',
#   'between',
#   'SA',
#   ',',
#   'US',
#   'in',
#   'jeopardy',
#   '|',
#   'eNCA',
#   'https://t.co/RwWHQfJkwv',
#   '\n'],
#  ['New',
#   'Event',
#   'Now',
#   'On',
#   '.',
#   'get',
#   'New',
#   'Rank',
#   'S',
#   'Monsters',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/kYjKZwsZjl',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/Gzx32HHMWU',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['@jasondemanzo',
#   'it',
#   'will',
#   'give',
#   'you',
#   'something',
#   'to',
#   'google',
#   'since',
#   'you',
#   'think',
#   'you',
#   'know',
#   'so',
#   'much',
#   '\n'],
#  ['*',
#   'try',
#   'to',
#   'find',
#   'bootleg',
#   'version',
#   'of',
#   'TFA',
#   'on',
#   'google',
#   '*',
#   '\n'],
#  ['The',
#   'best',
#   'advice',
#   'I',
#   'have',
#   'ever',
#   'receive',
#   'from',
#   'Google',
#   '-',
#   'how',
#   'to',
#   'numb',
#   'emotional',
#   'pain',
#   'https://t.co/bjD8pJ5Zyw',
#   '\n'],
#  ['Thanks',
#   'for',
#   'follow',
#   '@egibis_blog',
#   '!',
#   'look',
#   'for',
#   'me',
#   'on',
#   'FB',
#   ',',
#   'Google+',
#   ',',
#   'LinkedIn',
#   '&',
#   'amp',
#   ';',
#   'Pinterest',
#   'under',
#   'truCrowd',
#   '!',
#   'see',
#   'ya',
#   'there',
#   '!',
#   '\n'],
#  ['ECO',
#   '302',
#   'WEEK',
#   '3',
#   'QUIZ',
#   'STRAYER-',
#   'https://t.co/BURTA5bO3w',
#   '\n'],
#  ['7',
#   '"',
#   'A33',
#   'Google',
#   'Android',
#   '4.4',
#   'Quad',
#   'Core',
#   'Dual',
#   'Camera',
#   '8',
#   'GB',
#   'Tablet',
#   'PC',
#   'WiFi',
#   'Bluetooth',
#   '-',
#   'Bid',
#   'Now',
#   '!',
#   'On',
#   '…',
#   'https://t.co/OEtVgkSzm3',
#   'https://t.co/RJbkScWj2Y',
#   '\n'],
#  ['#',
#   'Google',
#   'to',
#   'analyze',
#   'if',
#   'rooftop',
#   'solar',
#   'panels',
#   'be',
#   'a',
#   'good',
#   'deal',
#   'https://t.co/rRMKYYufE6',
#   '\n'],
#  ['#',
#   'Google',
#   'to',
#   'analyze',
#   'if',
#   'rooftop',
#   'solar',
#   'panels',
#   'be',
#   'a',
#   'good',
#   'deal',
#   'https://t.co/5DFsj2V9Zf',
#   '\n'],
#  ['@wisdom_stars',
#   'Summary',
#   'of',
#   '"',
#   'The',
#   'Rise',
#   'of',
#   'Hate',
#   'Search',
#   '.',
#   '"',
#   '#',
#   'wisdomstarsnews',
#   '#',
#   'hatecrimes',
#   '#',
#   'Google',
#   '#',
#   'terrorism',
#   '#',
#   'ParisAttacks',
#   'https://t.co/f4pBPh1b7F',
#   '\n'],
#  ['Reliable',
#   'Seattle',
#   'town',
#   'car',
#   'hire',
#   'services',
#   '.For',
#   'more',
#   'information',
#   'click',
#   'on',
#   'this',
#   'link',
#   'https://t.co/Kuq5UnwWGq',
#   '.',
#   '\n'],
#  ['King',
#   'of',
#   'dark',
#   'fantasy',
#   '.',
#   'Summon',
#   'today',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/hN48FAuPZD',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/gf34ZsWpm9',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['listen',
#   'to',
#   'Something',
#   'You',
#   'Forgot',
#   '(',
#   'Carter',
#   '3',
#   ')',
#   'by',
#   'Lil',
#   "'",
#   'Wanye',
#   '|',
#   'https://t.co/Nu3vQf8Pfh',
#   '\n'],
#  ['RT',
#   '@Dave_RI',
#   ':',
#   'Top',
#   '10',
#   'Google',
#   'Docs',
#   'Posts',
#   'of',
#   '2015',
#   'https://t.co/L6SPrPFTjT',
#   'via',
#   '@alicekeeler',
#   '#',
#   'edtech',
#   '\n'],
#  ['@poptivist',
#   '@buttercupcas',
#   'HERE',
#   'YOU',
#   'go',
#   'I',
#   'hope',
#   'IT',
#   'WORKS',
#   'https://t.co/2LC6SkY1WQ',
#   '\n'],
#  ['gOOgle', ' ', 'https://t.co/scc7Pt3KNZ', '\n'],
#  ['The',
#   'Associated',
#   'Press',
#   ':',
#   'Steelers',
#   'sneak',
#   'into',
#   'AFC',
#   'playoffs',
#   'with',
#   '28',
#   '-',
#   '12',
#   'win',
#   'over',
#   'Browns',
#   '.',
#   'https://t.co/3zZGgjyp9e',
#   '\n'],
#  ['RT',
#   '@GoogleExpertUK',
#   ':',
#   'would',
#   'your',
#   'company',
#   'benefit',
#   'from',
#   'a',
#   'tailored',
#   '#',
#   'Google',
#   '&',
#   'amp',
#   ';',
#   '#',
#   'SocialMedia',
#   'seminar',
#   '?',
#   '0161',
#   '432',
#   '7268',
#   'https://t.co/rkfnLTbsMD',
#   'https',
#   ':',
#   '…',
#   '\n'],
#  ['https://t.co/sy3DaQnYBt',
#   '—',
#   'i',
#   'just',
#   'see',
#   'this',
#   '..',
#   'thank',
#   'you',
#   'for',
#   'share',
#   'it',
#   ':)',
#   'https://t.co/FkL5CKChbv',
#   '\n'],
#  ['Waka',
#   'Flocka',
#   '&',
#   'amp',
#   ';',
#   'Young',
#   'Sizzle',
#   '-',
#   'New',
#   'Year',
#   '(',
#   'Prod',
#   '.',
#   'By',
#   'Luke',
#   ')',
#   'https://t.co/SeK0tlclgh',
#   '\n'],
#  ['@JeremyLawrencee',
#   'ya',
#   'FIOS',
#   'here',
#   'at',
#   'my',
#   'place',
#   'and',
#   'at',
#   'my',
#   'parents',
#   '.',
#   'Hopefully',
#   'we',
#   'get',
#   'Google',
#   'fiber',
#   'here',
#   '\n'],
#  ['spyhuman',
#   'be',
#   'mobile',
#   'track',
#   'application',
#   'gps',
#   ' ',
#   'call',
#   'logs',
#   ',',
#   'call',
#   'recording',
#   '\n'],
#  ['https://t.co/x8TRf1SU0O', '\n'],
#  ['So',
#   'thankful',
#   'for',
#   'the',
#   'Google',
#   'Chromecast',
#   'let',
#   'me',
#   'stream',
#   'music',
#   'from',
#   'my',
#   'phone',
#   'to',
#   'my',
#   'tv🙏🙏🙏🙏',
#   '\n'],
#  ['RT',
#   '@GoogleExpertUK',
#   ':',
#   '#',
#   'Google',
#   'support',
#   'Swedish',
#   'Chef',
#   'from',
#   'The',
#   'Muppets',
#   '!',
#   '@MuppetsStudio',
#   '#',
#   'internet',
#   '#',
#   'technology',
#   'https://t.co/YjupLi6aMA',
#   '\n'],
#  ['RT',
#   '@LovinGianni',
#   ':',
#   'come',
#   'at',
#   'me',
#   'with',
#   'something',
#   'that',
#   'be',
#   ' ',
#   'grammatically',
#   'incorrect',
#   'I',
#   'be',
#   'fire',
#   'yo',
#   'ass',
#   'up',
#   'with',
#   'words',
#   'you',
#   'go',
#   'have',
#   'to',
#   'Google',
#   '.',
#   '\n'],
#  ['How',
#   'to',
#   'use',
#   'Google',
#   'effectively',
#   'https://t.co/7FQkrN0RPs',
#   '\n'],
#  ['RT',
#   '@wmsolomon',
#   ':',
#   'do',
#   "n't",
#   'use',
#   'google',
#   'for',
#   'your',
#   'research',
#   'just',
#   'read',
#   'history',
#   ',',
#   'it',
#   'be',
#   'fun',
#   ',',
#   'educate',
#   '&',
#   'amp',
#   ';',
#   'relevant',
#   '.',
#   'In',
#   'a',
#   'funny',
#   'way',
#   ',',
#   'History',
#   'keep',
#   'repeatin',
#   '…',
#   '\n'],
#  ['#',
#   'SocialMediaTips',
#   ':',
#   'Powerful',
#   'Personal',
#   'Branding',
#   'Tips',
#   'to',
#   'take',
#   'You',
#   'from',
#   'Digital',
#   'Zero',
#   '...',
#   'https://t.co/27uxxLf019',
#   '+',
#   'SMM↬https://t.co/2dOA1wsCRU',
#   '\n'],
#  ['#',
#   'SocialMediaTips',
#   ':',
#   'Powerful',
#   'Personal',
#   'Branding',
#   'Tips',
#   'to',
#   'take',
#   'You',
#   'from',
#   'Digital',
#   'Zero',
#   '...',
#   'https://t.co/UW7BkPII71',
#   '+',
#   'SMM↬https://t.co',
#   '/',
#   'VneDwWKkhb',
#   '\n'],
#  ['Sometimes',
#   'I',
#   'call',
#   '303',
#   '-',
#   '499',
#   '-',
#   '7111',
#   'and',
#   'listen',
#   'to',
#   'the',
#   'atomic',
#   'clock',
#   'at',
#   'NIST',
#   'tick',
#   'off',
#   'seconds',
#   '.',
#   '"',
#   'At',
#   'the',
#   'tone',
#   ',',
#   '5:44',
#   'UTC',
#   '"',
#   'https://t.co/W2id51EpX2',
#   '\n'],
#  ['Microsoft',
#   'will',
#   'inform',
#   'You',
#   'If',
#   'Government',
#   'be',
#   'spy',
#   'on',
#   'You',
#   'https://t.co/1uPEDcWKE8',
#   '\n'],
#  ['@MEsipisu',
#   'NEW',
#   'VIDEO',
#   'ALERT',
#   '!',
#   '!',
#   'https://t.co/NTs3QM5YU5',
#   '\n'],
#  ['RT',
#   '@SurajRaviFan',
#   ':',
#   '#',
#   'MIRUTHANtrailer',
#   'rock',
#   '@Youtube',
#   'with',
#   '6',
#   'Lakhs+',
#   'Views',
#   '&',
#   'amp',
#   ';',
#   '8K+',
#   'Likes',
#   '@actor_jayamravi',
#   '@shaktirajan',
#   '#',
#   'TheriHIT',
#   'https://t.co/7T',
#   '…',
#   '\n'],
#  ['King',
#   'of',
#   'dark',
#   'fantasy',
#   '.',
#   'Summon',
#   'today',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/17X4BV1hbG',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/qynhV3c83a',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['Zaker',
#   'Pro',
#   ':',
#   'Azkar',
#   'Muslim',
#   'pray',
#   '-',
#   'Android',
#   'Apps',
#   'on',
#   'Google',
#   'Play',
#   'https://t.co/fvwHOsVdcC',
#   '\n'],
#  ['write',
#   'an',
#   'Android',
#   'application',
#   ' ',
#   'by',
#   'patilvaibhavp99',
#   'https://t.co/klyemTUGzL',
#   'I',
#   'want',
#   'to',
#   'integrate',
#   'google',
#   'auto',
#   'complete',
#   'place',
#   ' ',
#   'API',
#   'in',
#   'android',
#   'ap',
#   '…',
#   '\n'],
#  ['.@sardesairajdeep',
#   'It',
#   'take',
#   '58',
#   'minutes',
#   'now',
#   'as',
#   'per',
#   'Google',
#   'maps',
#   '...',
#   'unless',
#   'of',
#   'course',
#   'Google',
#   'be',
#   'a',
#   'Modi',
#   'agent',
#   '.',
#   'https://t.co/flMt7tFYwu',
#   '\n'],
#  ['UNIVERSO',
#   'NOKIA',
#   ':',
#   'NewsSpot',
#   '!',
#   'Google',
#   'reader',
#   'potente',
#   'e',
#   'versatile',
#   '!',
#   'https://t.co/0kaUc01saT',
#   '\n'],
#  ['RT',
#   '@koderedapps',
#   ':',
#   'check',
#   'out',
#   'our',
#   '#',
#   'new',
#   '#',
#   'android',
#   '#',
#   'game',
#   '#',
#   'RoadRage',
#   'https://t.co/38bQtBEYOm',
#   '#',
#   'endless',
#   '#',
#   'free',
#   '#',
#   'addictive',
#   '#',
#   'shooter',
#   '#',
#   'racing',
#   '#',
#   'rockets',
#   '#',
#   'b',
#   '…',
#   '\n'],
#  ['RT',
#   '@bella230893',
#   ':',
#   '[',
#   'Preview',
#   ']',
#   'BestPlan',
#   '!',
#   'Calendar',
#   'by',
#   '@PlanBAP',
#   '\n'],
#  ['To',
#   'order',
#   'please',
#   'refer',
#   'here',
#   '👇🏻(Malaysia',
#   'go',
#   ')',
#   'https://t.co/UWzYuNmwHV',
#   'https://t.co/',
#   '…',
#   '\n'],
#  ['1451886241-Weekly',
#   'European',
#   'Tour',
#   'Fantasy',
#   'Golf',
#   'App',
#   'for',
#   'Android',
#   'https://t.co/4hsePaDOwT',
#   '\n'],
#  ['The',
#   'Associated',
#   'Press',
#   ':',
#   'Vikings',
#   'take',
#   'NFC',
#   'North',
#   ',',
#   'hold',
#   'on',
#   'to',
#   'beat',
#   'Packers',
#   '20',
#   '-',
#   '13',
#   '.',
#   'https://t.co/3c9NfB3Kxg',
#   '\n'],
#  ['King',
#   'of',
#   'dark',
#   'fantasy',
#   '.',
#   'Summon',
#   'today',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/S4is1P6krB',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/fQvCcpLWXl',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['New',
#   'Event',
#   'Now',
#   'On',
#   '.',
#   'get',
#   'New',
#   'Rank',
#   'S',
#   'Monsters',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/CO72KI2eA5',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/X3b0CL0DDD',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ['@EmmaaJoyce',
#   '@chichenry',
#   'I',
#   'look',
#   'it',
#   'up',
#   'on',
#   'google',
#   'and',
#   'it',
#   'give',
#   'me',
#   'nothing',
#   '\n'],
#  ['I',
#   'just',
#   'receive',
#   'a',
#   'reward',
#   ':',
#   'Legendary',
#   'Island',
#   '!',
#   'https://t.co/UzAqFNNif0',
#   '#',
#   'Android',
#   '#',
#   'Gameinsight',
#   '#',
#   'Androidgames',
#   '\n'],
#  ['New',
#   'Event',
#   'Now',
#   'On',
#   '.',
#   'get',
#   'New',
#   'Rank',
#   'S',
#   'Monsters',
#   '.',
#   'App',
#   'Store',
#   ':',
#   'https://t.co/s9dkLyvOvA',
#   'Google',
#   'play',
#   ':',
#   'https://t.co/nmwqU8hDkX',
#   '#',
#   'DarkSummoner',
#   '\n'],
#  ...]

# %% [markdown]
# ### Exercise 2b:
# Build a `word2vec` model.
# Test the window size as well - this is how many surrounding words need to be used to model a word. What do you think is appropriate for Twitter?

# %%
model = Word2Vec(text_split, size=100, window=4, min_count=5, workers=4)

# %%
print (model)
# Out:
# Word2Vec(vocab=1732, size=100, alpha=0.025)

# %% [markdown]
# ### Exercise 2c:
# Test your word2vec model with a few similarity functions.
# * Find words similar to 'Syria'.
# * Find words similar to 'war'.
# * Find words similar to "Iran".
# * Find words similar to 'Verizon'.

# %%
model.most_similar(positive=['France'])
# Out:
# [('Paris', 0.999576210975647),
#  ('News', 0.9994099140167236),
#  ('UK', 0.9993443489074707),
#  ('MTP', 0.9992794394493103),
#  ('|', 0.9991250038146973),
#  ('FNS', 0.9990339875221252),
#  ('TEAMGOT7', 0.9989665746688843),
#  ('USA', 0.9989305734634399),
#  ('More', 0.9988043308258057),
#  ('https://', 0.9986587762832642)]

# %% [markdown]
# # Exercise 2d
#
# Adjust the choices / parameters in (b) and (c) as necessary.

# %% [markdown]
# ## Exercise 3
#
# Filter tweets to those that mention 'Iran' or similar entities and 'war' or similar entities.
# * Do this using just spacy.
# * Do this using word2vec similarity scores.

# %%
# Using spacy
for tweet in tweets:
    parsed = nlp_toolkit(tweet)
    pass

# %%
# Using word2vec similarity scores
for tweet in tweets[:200]:
    parsed = nlp_toolkit(tweet)
    pass
